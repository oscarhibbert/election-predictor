# %%
import pandas as pd
# Imports CSV
df = pd.read_csv('../raw_data/constituency_raw.csv')
# Reduces CSV to relevant election years
filtered_df = df[df['Election Year'].isin([2005, 2010, 2015, 2017])]
#Creates new index
filtered_df['new_index'] = filtered_df['Election Year'].astype(str) + '_' + filtered_df['Constituency'] + '_' + filtered_df['Boundary Year'].astype(str)
# Pivots table for the first time
pivot_votes_df = filtered_df.pivot_table(
    index=['Election Year', 'Boundary Year', 'Constituency', 'Candidate','Party', 'new_index'],
    values='Votes',
    fill_value=0
).reset_index()
# Out:
# /tmp/ipykernel_57767/408073463.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['new_index'] = filtered_df['Election Year'].astype(str) + '_' + filtered_df['Constituency'] + '_' + filtered_df['Boundary Year'].astype(str)

# %%
# Reduces CSV to relevant parties
parties_cleaned = pivot_votes_df.reset_index(drop=False)['Party'].apply(lambda x: x if x in ['British National Party', 'The Brexit Party', 'Conservative', 'Green Party', 'Liberal Democrats', 'Labour', 'Plaid Cymru', 'SNP', 'UK Independence Party (UKIP)'] else 'Other')
pivot_votes_df['Party_cleaned'] = parties_cleaned

# %%
#Drops irrelevant columns
pivot_votes_df.drop(columns='Party', inplace=True)
pivot_votes_df.set_index('new_index', inplace=True)

# %%
# Makes second pivot
pivot_table = pd.pivot_table(pivot_votes_df,
                             index=['new_index'],
                             columns=['Party_cleaned'],
                             values='Votes',
                             aggfunc='sum',
                             fill_value=0)

# %%
# Renames columns to follow our style
rename_dict = {
    'British National Party': 'NAT_ACTUAL_CONS',
    'Conservative': 'CON_ACTUAL_CONS',
    'Green Party': 'GRE_ACTUAL_CONS',
    'Liberal Democrats': 'LIB_ACTUAL_CONS',
    'Labour': 'LAB_ACTUAL_CONS',
    'Plaid Cymru': 'PLC_ACTUAL_CONS',
    'SNP': 'SNP_ACTUAL_CONS',
    'UK Independence Party (UKIP)': 'UKI_ACTUAL_CONS',
    'Other': 'OTH_ACTUAL_CONS'
}
pivot_table.rename(columns=rename_dict, inplace=True)

# %%
#Readds relevant columns
pivot_table['Election Year'] = pivot_table.index.str.split('_').str[0].astype(int)
pivot_table['Constituency'] = pivot_table.index.str.split('_').str[1]
pivot_table['Boundary Year'] = pivot_table.index.str.split('_').str[2]

# %%
# Reorders columns
columns_reordered = ['Constituency', 'Election Year', 'Boundary Year',
                     'CON_ACTUAL_CONS', 'GRE_ACTUAL_CONS', 'LAB_ACTUAL_CONS',
                     'LIB_ACTUAL_CONS', 'NAT_ACTUAL_CONS', 'OTH_ACTUAL_CONS', 'PLC_ACTUAL_CONS',
                     'SNP_ACTUAL_CONS', 'UKI_ACTUAL_CONS']
df_final = pivot_table[columns_reordered]

# %%
# Calculates total votes
df_final['total_votes'] = df_final[['CON_ACTUAL_CONS', 'GRE_ACTUAL_CONS', 'LAB_ACTUAL_CONS', 'LIB_ACTUAL_CONS',
                  'NAT_ACTUAL_CONS', 'OTH_ACTUAL_CONS', 'PLC_ACTUAL_CONS', 'SNP_ACTUAL_CONS',
                  'UKI_ACTUAL_CONS']].sum(axis=1)
# Out:
# /tmp/ipykernel_57767/1285122342.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['total_votes'] = df_final[['CON_ACTUAL_CONS', 'GRE_ACTUAL_CONS', 'LAB_ACTUAL_CONS', 'LIB_ACTUAL_CONS',

# %%
# Switches to percentage
df_percentage = df_final[['CON_ACTUAL_CONS', 'GRE_ACTUAL_CONS', 'LAB_ACTUAL_CONS', 'LIB_ACTUAL_CONS', 'NAT_ACTUAL_CONS',
                    'OTH_ACTUAL_CONS', 'PLC_ACTUAL_CONS', 'SNP_ACTUAL_CONS',
                    'UKI_ACTUAL_CONS']].div(df_final['total_votes'], axis=0) * 100

# %%
df_result = pd.concat([df_final[['Election Year', 'Constituency']], df_percentage], axis=1)

# %%
df_result.rename(columns={'Election Year': 'election_year'}, inplace=True)

# %%
df_result
# Out:
# Party_cleaned                                election_year  \
# new_index
# 2005_Aberavon_2005                                    2005
# 2005_Aberdeen North_2005                              2005
# 2005_Aberdeen South_2005                              2005
# 2005_Aberdeenshire West and Kincardine_2005           2005
# 2005_Airdrie and Shotts_2005                          2005
# ...                                                    ...
# 2017_Yeovil_2010                                      2017
# 2017_Ynys Mon_2010                                    2017
# 2017_York Central_2010                                2017
# 2017_York Outer_2010                                  2017
# 2017_Yorkshire East_2010                              2017
#
# Party_cleaned                                                     Constituency  \
# new_index
# 2005_Aberavon_2005                                                    Aberavon
# 2005_Aberdeen North_2005                                        Aberdeen North
# 2005_Aberdeen South_2005                                        Aberdeen South
# 2005_Aberdeenshire West and Kincardine_2005  Aberdeenshire West and Kincardine
# 2005_Airdrie and Shotts_2005                                Airdrie and Shotts
# ...                                                                        ...
# 2017_Yeovil_2010                                                        Yeovil
# 2017_Ynys Mon_2010                                                    Ynys Mon
# 2017_York Central_2010                                            York Central
# 2017_York Outer_2010                                                York Outer
# 2017_Yorkshire East_2010                                        Yorkshire East
#
# Party_cleaned                                CON_ACTUAL_CONS  GRE_ACTUAL_CONS  \
# new_index
# 2005_Aberavon_2005                                 10.178049         1.694127
# 2005_Aberdeen North_2005                            9.433859         0.000000
# 2005_Aberdeen South_2005                           17.140386         0.000000
# 2005_Aberdeenshire West and Kincardine_2005        28.366308         0.000000
# 2005_Airdrie and Shotts_2005                        9.864889         0.000000
# ...                                                      ...              ...
# 2017_Yeovil_2010                                   54.489597         1.770925
# 2017_Ynys Mon_2010                                 27.789226         0.000000
# 2017_York Central_2010                             30.174427         0.000000
# 2017_York Outer_2010                               51.118812         1.905027
# 2017_Yorkshire East_2010                           58.273408         1.747720
#
# Party_cleaned                                LAB_ACTUAL_CONS  LIB_ACTUAL_CONS  \
# new_index
# 2005_Aberavon_2005                                 60.048499        13.752325
# 2005_Aberdeen North_2005                           42.466015        23.917672
# 2005_Aberdeen South_2005                           36.693016        33.454266
# 2005_Aberdeenshire West and Kincardine_2005        13.133884        46.304745
# 2005_Airdrie and Shotts_2005                       59.014416        11.436154
# ...                                                      ...              ...
# 2017_Yeovil_2010                                   12.487375        29.705070
# 2017_Ynys Mon_2010                                 41.863141         1.281880
# 2017_York Central_2010                             65.163502         4.662071
# 2017_York Outer_2010                               36.684835        10.291326
# 2017_Yorkshire East_2010                           30.461858         3.955075
#
# Party_cleaned                                NAT_ACTUAL_CONS  OTH_ACTUAL_CONS  \
# new_index
# 2005_Aberavon_2005                                       0.0         2.551156
# 2005_Aberdeen North_2005                                 0.0         1.886226
# 2005_Aberdeen South_2005                                 0.0         2.813484
# 2005_Aberdeenshire West and Kincardine_2005              0.0         0.910008
# 2005_Airdrie and Shotts_2005                             0.0         3.145546
# ...                                                      ...              ...
# 2017_Yeovil_2010                                         0.0         1.547034
# 2017_Ynys Mon_2010                                       0.0         0.000000
# 2017_York Central_2010                                   0.0         0.000000
# 2017_York Outer_2010                                     0.0         0.000000
# 2017_Yorkshire East_2010                                 0.0         1.881162
#
# Party_cleaned                                PLC_ACTUAL_CONS  SNP_ACTUAL_CONS  \
# new_index
# 2005_Aberavon_2005                                 11.775844         0.000000
# 2005_Aberdeen North_2005                            0.000000        22.296228
# 2005_Aberdeen South_2005                            0.000000         9.898849
# 2005_Aberdeenshire West and Kincardine_2005         0.000000        11.285056
# 2005_Airdrie and Shotts_2005                        0.000000        16.538995
# ...                                                      ...              ...
# 2017_Yeovil_2010                                    0.000000         0.000000
# 2017_Ynys Mon_2010                                 27.395831         0.000000
# 2017_York Central_2010                              0.000000         0.000000
# 2017_York Outer_2010                                0.000000         0.000000
# 2017_Yorkshire East_2010                            0.000000         0.000000
#
# Party_cleaned                                UKI_ACTUAL_CONS
# new_index
# 2005_Aberavon_2005                                  0.000000
# 2005_Aberdeen North_2005                            0.000000
# 2005_Aberdeen South_2005                            0.000000
# 2005_Aberdeenshire West and Kincardine_2005         0.000000
# 2005_Airdrie and Shotts_2005                        0.000000
# ...                                                      ...
# 2017_Yeovil_2010                                    0.000000
# 2017_Ynys Mon_2010                                  1.669923
# 2017_York Central_2010                              0.000000
# 2017_York Outer_2010                                0.000000
# 2017_Yorkshire East_2010                            3.680777
#
# [2596 rows x 11 columns]

# %%
# Imports national election results to concatenante
election_results_df = pd.read_csv('../processed_data/election_results_dataframe.csv')
election_results_df.rename(columns={'Year': 'election_year'}, inplace=True)

# %%
election_results_df.rename(columns={'Year': 'election_year'}, inplace=True)

# %%
# Merges national onto constituency election results
cons_result_comp = df_result.merge(election_results_df, on='election_year', how='left')

# %%
# Renames national result columns
rename_dict2 = {
    'BRX_ACTUAL_PERCENTAGE': 'BRX_NAT_RESULT',
    'CON_ACTUAL_PERCENTAGE': 'CON_NAT_RESULT',
    'GRE_ACTUAL_PERCENTAGE': 'GRE_NAT_RESULT',
    'LIB_ACTUAL_PERCENTAGE': 'LIB_NAT_RESULT',
    'LABOUR_ACTUAL_PERCENTAGE': 'LAB_NAT_RESULT',
    'NAT_ACTUAL_PERCENTAGE': 'NAT_NAT_RESULT',
    'PLC_ACTUAL_PERCENTAGE': 'PLC_NAT_RESULT',
    'SNP_ACTUAL_PERCENTAGE': 'SNP_NAT_RESULT',
    'UKI_ACTUAL_PERCENTAGE': 'UKI_NAT_RESULT',
    'OTH_PERCENTAGE': 'OTH_NAT_RESULT'
}
cons_result_comp.rename(columns=rename_dict2, inplace=True)

# %%
# Drops and renames columns
cons_result_comp.drop(columns=['Geography', 'Country'], inplace=True)
cons_result_comp.rename(columns={'CON_ACT_CONS': 'CON_ACTUAL_CONS'}, inplace=True)
cons_result_comp.rename(columns={'BRX_ACT_CONS': 'BRX_ACTUAL_CONS'}, inplace=True)

# %%
# Calculates bias score
for index, row in cons_result_comp.iterrows():
    bias_scores = {}
    # Loop through each party
    for party in ['CON', 'GRE', 'LAB', 'LIB', 'NAT', 'OTH', 'PLC', 'SNP', 'UKI']:
        # Calculate the absolute difference between the constituency result and national result for each party
        bias_scores[party] = (row[f'{party}_ACTUAL_CONS'] - row[f'{party}_NAT_RESULT'])
    # Assign the bias scores to the respective columns
    for party, score in bias_scores.items():
        cons_result_comp.loc[index, f'{party}_Bias_Score'] = score

# %%
# Filters datafra,e
biases_df = cons_result_comp.filter(like='Bias')

# %%
# Calculates bias per constituency
average_biases_per_constituency = biases_df.groupby(cons_result_comp['Constituency']).mean()

# %%
average_biases_per_constituency
# Out:
#                                    CON_Bias_Score  GRE_Bias_Score  \
# Constituency
# Aberavon                               -23.383095       -0.776212
# Aberconwy                                2.237431       -1.231315
# Aberdeen North                         -22.748165       -1.763618
# Aberdeen South                         -11.186185       -1.763618
# Aberdeenshire West and Kincardine       -3.062077       -1.763618
# ...                                           ...             ...
# Ynys Mon                               -16.271884       -1.763618
# York Central                           -10.215902        2.511350
# York Outer                               9.339253        0.181736
# York, City of                           -7.971759        3.585537
# Yorkshire East                          13.485821       -0.089354
#
#                                    LAB_Bias_Score  LIB_Bias_Score  \
# Constituency
# Aberavon                                23.593507       -6.011279
# Aberconwy                               -1.362923       -3.805160
# Aberdeen North                           2.054465       -2.132780
# Aberdeen South                          -3.520760        3.013810
# Aberdeenshire West and Kincardine      -23.074161       13.617842
# ...                                           ...             ...
# Ynys Mon                                 1.588433      -10.628608
# York Central                            16.028050       -0.155499
# York Outer                              -6.964496        6.574726
# York, City of                           11.674199       -0.208700
# Yorkshire East                          -7.837766       -2.477353
#
#                                    NAT_Bias_Score  OTH_Bias_Score  \
# Constituency
# Aberavon                                 0.372713       -0.574823
# Aberconwy                               -0.640285       -3.313033
# Aberdeen North                          -0.236639       -2.465155
# Aberdeen South                          -0.350401       -2.101086
# Aberdeenshire West and Kincardine       -0.373945       -3.000303
# ...                                           ...             ...
# Ynys Mon                                -0.657716        1.987405
# York Central                             0.199448       -2.950186
# York Outer                              -0.042412       -3.465428
# York, City of                           -0.710007       -3.759991
# Yorkshire East                           0.251969       -2.416338
#
#                                    PLC_Bias_Score  SNP_Bias_Score  \
# Constituency
# Aberavon                                 9.122838       -2.736884
# Aberconwy                               12.584204       -3.142973
# Aberdeen North                          -0.575947       32.822584
# Aberdeen South                          -0.575947       20.977045
# Aberdeenshire West and Kincardine       -0.575947       22.511700
# ...                                           ...             ...
# Ynys Mon                                28.224095       -2.736884
# York Central                            -0.553252       -3.142973
# York Outer                              -0.553252       -3.142973
# York, City of                           -0.644030       -1.518620
# Yorkshire East                          -0.575947       -2.736884
#
#                                    UKI_Bias_Score
# Constituency
# Aberavon                                 0.393236
# Aberconwy                               -1.325945
# Aberdeen North                          -4.954744
# Aberdeen South                          -4.492859
# Aberdeenshire West and Kincardine       -4.279491
# ...                                           ...
# Ynys Mon                                 0.258776
# York Central                            -1.721036
# York Outer                              -1.927154
# York, City of                           -0.446629
# Yorkshire East                           2.395851
#
# [731 rows x 9 columns]

# %%
 average_biases_per_constituency.to_csv('../processed_data/removes_2019_constituency_bias_dataframe.csv', index=True)

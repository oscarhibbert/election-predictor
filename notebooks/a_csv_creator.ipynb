# %%
import pandas as pd

# Load predictions from csvs
uk_df_dct = {}
uk_df_dct['actuals_df'] = pd.read_excel('../processed_data/election_tracker.xlsx', sheet_name='actuals', index_col=0)
uk_df_dct['polls_avg_df'] = pd.read_excel('../processed_data/election_tracker.xlsx', sheet_name='polls_average', index_col=0)
uk_df_dct['polls_model_df'] = pd.read_excel('../processed_data/election_tracker.xlsx', sheet_name='polls_model', index_col=0)
uk_df_dct['polls_eco_df'] = pd.read_excel('../processed_data/election_tracker.xlsx', sheet_name='polls_eco', index_col=0)
uk_df_dct['polls_alt_df'] = pd.read_excel('../processed_data/election_tracker.xlsx', sheet_name='polls_alt', index_col=0)
uk_df_dct['polls_eco_alt_df'] = pd.read_excel('../processed_data/election_tracker.xlsx', sheet_name='polls_eco_alt', index_col=0)

# Load Scottish forecast data
scotland_df = pd.read_excel('../processed_data/election_tracker.xlsx', sheet_name='scotland', index_col=0)

# Define the forecast models
forecast_models = uk_df_dct.copy()

# Import the test bias data
test_bias = pd.read_csv('../processed_data/last_bias.csv', index_col=0)

def calculate_predicted_vote_share(forecast, bias_scores):
    predicted_vote_share = {}
    for party, forecast_share in forecast.items():
        bias_score = bias_scores.get(f"{party}_Bias_Score", 0)
        predicted_vote_share[party] = forecast_share + bias_score
    return predicted_vote_share

def determine_winner(predicted_vote_share):
    return max(predicted_vote_share, key=predicted_vote_share.get)

def determine_winners(forecast, bias_dataframe):
    winners = []
    for index, row in bias_dataframe.iterrows():
        predicted_vote_share = calculate_predicted_vote_share(forecast, row)
        winner = determine_winner(predicted_vote_share)
        winners.append({'Constituency': index, 'Winner': winner})
    return pd.DataFrame(winners)

# Separate Scottish and non-Scottish constituencies in the bias data
scottish_bias = test_bias[test_bias['Scotland'] == True]
uk_test_bias = test_bias[test_bias['Scotland'] == False]

# Container for results
total_constituencies_results = {}
constituency_winners_results = {}

# Loop through each model and each forecast year
for model_name, forecast_df in forecast_models.items():
    model_results = {}
    constituency_winners = {}
    for year in forecast_df.columns:
        forecast = forecast_df[year].dropna().to_dict()
        scotland_forecast = scotland_df[year].dropna().to_dict()

        # Determine winners for UK (excluding Scotland)
        uk_winners_df = determine_winners(forecast, uk_test_bias)
        uk_total_constituencies = uk_winners_df['Winner'].value_counts().reset_index()
        uk_total_constituencies.columns = ['Party', 'Total_Constituencies']

        # Determine winners for Scotland
        scotland_winners_df = determine_winners(scotland_forecast, scottish_bias)
        scotland_total_constituencies = scotland_winners_df['Winner'].value_counts().reset_index()
        scotland_total_constituencies.columns = ['Party', 'Total_Constituencies']

        # Concatenate the results
        total_constituencies = pd.concat([uk_total_constituencies, scotland_total_constituencies]).groupby('Party').sum().reset_index()

        # Concatenate the constituency winners
        winners_df = pd.concat([uk_winners_df, scotland_winners_df])

        model_results[year] = total_constituencies
        constituency_winners[year] = winners_df

    total_constituencies_results[model_name] = model_results
    constituency_winners_results[model_name] = constituency_winners

# Create an Excel writer
with pd.ExcelWriter('election_results.xlsx') as writer:
    # Write total constituencies results to Excel
    for model_name, results in total_constituencies_results.items():
        for year, df in results.items():
            sheet_name = f"{model_name}_{year}_total"
            df.to_excel(writer, sheet_name=sheet_name, index=False)

    # Write constituency winners results to Excel
    for model_name, results in constituency_winners_results.items():
        for year, df in results.items():
            sheet_name = f"{model_name}_{year}_winners"
            df.to_excel(writer, sheet_name=sheet_name, index=False)

# Display the results for verification
for model_name, results in total_constituencies_results.items():
    print(f"Results for model: {model_name}")
    for year, df in results.items():
        print(f"Year: {year}")
        print(df)
        print()

for model_name, results in constituency_winners_results.items():
    print(f"Constituency Winners for model: {model_name}")
    for year, df in results.items():
        print(f"Year: {year}")
        print(df)
        print()
# Out:
# Results for model: actuals_df
# Year: 2010
#   Party  Total_Constituencies
# 0   CON                   321
# 1   GRE                     1
# 2   LAB                   264
# 3   LIB                    40
# 4   OTH                    19
# 5   PLC                     3
# 6   SNP                     2
#
# Year: 2015
#   Party  Total_Constituencies
# 0   CON                   337
# 1   GRE                     1
# 2   LAB                   227
# 3   LIB                     8
# 4   OTH                    19
# 5   PLC                     4
# 6   SNP                    54
#
# Year: 2017
#   Party  Total_Constituencies
# 0   CON                   326
# 1   GRE                     1
# 2   LAB                   246
# 3   LIB                     7
# 4   OTH                    19
# 5   PLC                     4
# 6   SNP                    47
#
# Year: 2019
#   Party  Total_Constituencies
# 0   CON                   363
# 1   GRE                    50
# 2   LAB                   203
# 3   LIB                    10
# 4   OTH                    19
# 5   PLC                     4
# 6   SNP                     1
#
# Year: 2024
#        Party  Total_Constituencies
# 0  BRX + UKI                    16
# 1        CON                   148
# 2        GRE                     1
# 3        LAB                   450
# 4        LIB                    29
# 5        SNP                     6
#
# Results for model: polls_avg_df
# Year: 2010
#   Party  Total_Constituencies
# 0   CON                   331
# 1   GRE                     1
# 2   LAB                   264
# 3   LIB                    30
# 4   OTH                    19
# 5   PLC                     3
# 6   SNP                     2
#
# Year: 2015
#   Party  Total_Constituencies
# 0   CON                   293
# 1   GRE                     1
# 2   LAB                   266
# 3   LIB                    13
# 4   OTH                    19
# 5   PLC                     4
# 6   SNP                    54
#
# Year: 2017
#   Party  Total_Constituencies
# 0   CON                   411
# 1   GRE                     1
# 2   LAB                   160
# 3   LIB                     7
# 4   OTH                    19
# 5   PLC                     4
# 6   SNP                    48
#
# Year: 2019
#   Party  Total_Constituencies
# 0   CON                   358
# 1   GRE                    50
# 2   LAB                   196
# 3   LIB                    21
# 4   OTH                    19
# 5   PLC                     4
# 6   SNP                     2
#
# Year: 2024
#   Party  Total_Constituencies
# 0   CON                   147
# 1   GRE                     1
# 2   LAB                   446
# 3   LIB                    27
# 4   OTH                    19
# 5   PLC                     4
# 6   SNP                     6
#
# Results for model: polls_model_df
# Year: 2010
#   Party  Total_Constituencies
# 0   CON                   324
# 1   GRE                     1
# 2   LAB                   270
# 3   LIB                    31
# 4   OTH                    19
# 5   PLC                     3
# 6   SNP                     2
#
# Year: 2015
#   Party  Total_Constituencies
# 0   CON                   293
# 1   GRE                     1
# 2   LAB                   266
# 3   LIB                    13
# 4   OTH                    19
# 5   PLC                     4
# 6   SNP                    54
#
# Year: 2017
#   Party  Total_Constituencies
# 0   CON                   411
# 1   GRE                     1
# 2   LAB                   160
# 3   LIB                     7
# 4   OTH                    19
# 5   PLC                     4
# 6   SNP                    48
#
# Year: 2019
#   Party  Total_Constituencies
# 0   CON                   350
# 1   GRE                    50
# 2   LAB                   209
# 3   LIB                    18
# 4   OTH                    19
# 5   PLC                     3
# 6   SNP                     1
#
# Year: 2024
#   Party  Total_Constituencies
# 0   CON                   183
# 1   GRE                     1
# 2   LAB                   411
# 3   LIB                    26
# 4   OTH                    19
# 5   PLC                     4
# 6   SNP                     6
#
# Results for model: polls_eco_df
# Year: 2010
#   Party  Total_Constituencies
# 0   CON                   324
# 1   GRE                     1
# 2   LAB                   270
# 3   LIB                    31
# 4   OTH                    19
# 5   PLC                     3
# 6   SNP                     2
#
# Year: 2015
#   Party  Total_Constituencies
# 0   CON                   291
# 1   GRE                     1
# 2   LAB                   267
# 3   LIB                    14
# 4   OTH                    19
# 5   PLC                     4
# 6   SNP                    54
#
# Year: 2017
#   Party  Total_Constituencies
# 0   CON                   411
# 1   GRE                     1
# 2   LAB                   160
# 3   LIB                     7
# 4   OTH                    19
# 5   PLC                     4
# 6   SNP                    48
#
# Year: 2019
#   Party  Total_Constituencies
# 0   CON                   347
# 1   GRE                    50
# 2   LAB                   212
# 3   LIB                    18
# 4   OTH                    19
# 5   PLC                     3
# 6   SNP                     1
#
# Year: 2024
#   Party  Total_Constituencies
# 0   CON                   230
# 1   GRE                     1
# 2   LAB                   373
# 3   LIB                    17
# 4   OTH                    19
# 5   PLC                     4
# 6   SNP                     6
#
# Results for model: polls_alt_df
# Year: 2010
#   Party  Total_Constituencies
# 0   CON                   296
# 1   GRE                     1
# 2   LAB                   284
# 3   LIB                    45
# 4   OTH                    19
# 5   PLC                     3
# 6   SNP                     2
#
# Year: 2015
#   Party  Total_Constituencies
# 0   CON                   294
# 1   GRE                     1
# 2   LAB                   265
# 3   LIB                    13
# 4   OTH                    19
# 5   PLC                     4
# 6   SNP                    54
#
# Year: 2017
#   Party  Total_Constituencies
# 0   CON                   411
# 1   GRE                     1
# 2   LAB                   160
# 3   LIB                     7
# 4   OTH                    19
# 5   PLC                     4
# 6   SNP                    48
#
# Year: 2019
#   Party  Total_Constituencies
# 0   CON                   338
# 1   GRE                    50
# 2   LAB                   221
# 3   LIB                    18
# 4   OTH                    19
# 5   PLC                     3
# 6   SNP                     1
#
# Year: 2024
#   Party  Total_Constituencies
# 0   CON                   245
# 1   GRE                     1
# 2   LAB                   356
# 3   LIB                    19
# 4   OTH                    19
# 5   PLC                     4
# 6   SNP                     6
#
# Results for model: polls_eco_alt_df
# Year: 2010
#   Party  Total_Constituencies
# 0   CON                   301
# 1   GRE                     1
# 2   LAB                   286
# 3   LIB                    38
# 4   OTH                    19
# 5   PLC                     3
# 6   SNP                     2
#
# Year: 2015
#   Party  Total_Constituencies
# 0   CON                   289
# 1   GRE                     1
# 2   LAB                   270
# 3   LIB                    13
# 4   OTH                    19
# 5   PLC                     4
# 6   SNP                    54
#
# Year: 2017
#   Party  Total_Constituencies
# 0   CON                   411
# 1   GRE                     1
# 2   LAB                   160
# 3   LIB                     7
# 4   OTH                    19
# 5   PLC                     4
# 6   SNP                    48
#
# Year: 2019
#   Party  Total_Constituencies
# 0   CON                   333
# 1   GRE                    50
# 2   LAB                   225
# 3   LIB                    19
# 4   OTH                    19
# 5   PLC                     3
# 6   SNP                     1
#
# Year: 2024
#   Party  Total_Constituencies
# 0   CON                   219
# 1   GRE                     1
# 2   LAB                   381
# 3   LIB                    20
# 4   OTH                    19
# 5   PLC                     4
# 6   SNP                     6
#
# Constituency Winners for model: actuals_df
# Year: 2010
#                          Constituency Winner
# 0                    Aberafan Maesteg    LAB
# 1                           Aldershot    CON
# 2                 Aldridge-Brownhills    CON
# 3            Altrincham and Sale West    CON
# 4                    Alyn and Deeside    LAB
# ..                                ...    ...
# 51            Perth and Kinross-shire    SNP
# 52                         Rutherglen    LAB
# 53           Stirling and Strathallan    CON
# 54  West Aberdeenshire and Kincardine    LAB
# 55                West Dunbartonshire    LAB
#
# [650 rows x 2 columns]
#
# Year: 2015
#                          Constituency Winner
# 0                    Aberafan Maesteg    LAB
# 1                           Aldershot    CON
# 2                 Aldridge-Brownhills    CON
# 3            Altrincham and Sale West    CON
# 4                    Alyn and Deeside    LAB
# ..                                ...    ...
# 51            Perth and Kinross-shire    SNP
# 52                         Rutherglen    SNP
# 53           Stirling and Strathallan    SNP
# 54  West Aberdeenshire and Kincardine    SNP
# 55                West Dunbartonshire    SNP
#
# [650 rows x 2 columns]
#
# Year: 2017
#                          Constituency Winner
# 0                    Aberafan Maesteg    LAB
# 1                           Aldershot    CON
# 2                 Aldridge-Brownhills    CON
# 3            Altrincham and Sale West    CON
# 4                    Alyn and Deeside    LAB
# ..                                ...    ...
# 51            Perth and Kinross-shire    SNP
# 52                         Rutherglen    SNP
# 53           Stirling and Strathallan    CON
# 54  West Aberdeenshire and Kincardine    SNP
# 55                West Dunbartonshire    SNP
#
# [650 rows x 2 columns]
#
# Year: 2019
#                          Constituency Winner
# 0                    Aberafan Maesteg    LAB
# 1                           Aldershot    CON
# 2                 Aldridge-Brownhills    CON
# 3            Altrincham and Sale West    CON
# 4                    Alyn and Deeside    LAB
# ..                                ...    ...
# 51            Perth and Kinross-shire    GRE
# 52                         Rutherglen    GRE
# 53           Stirling and Strathallan    CON
# 54  West Aberdeenshire and Kincardine    GRE
# 55                West Dunbartonshire    GRE
#
# [650 rows x 2 columns]
#
# Year: 2024
#                          Constituency Winner
# 0                    Aberafan Maesteg    LAB
# 1                           Aldershot    CON
# 2                 Aldridge-Brownhills    CON
# 3            Altrincham and Sale West    LAB
# 4                    Alyn and Deeside    LAB
# ..                                ...    ...
# 51            Perth and Kinross-shire    SNP
# 52                         Rutherglen    LAB
# 53           Stirling and Strathallan    CON
# 54  West Aberdeenshire and Kincardine    LAB
# 55                West Dunbartonshire    LAB
#
# [650 rows x 2 columns]
#
# Constituency Winners for model: polls_avg_df
# Year: 2010
#                          Constituency Winner
# 0                    Aberafan Maesteg    LAB
# 1                           Aldershot    CON
# 2                 Aldridge-Brownhills    CON
# 3            Altrincham and Sale West    CON
# 4                    Alyn and Deeside    LAB
# ..                                ...    ...
# 51            Perth and Kinross-shire    SNP
# 52                         Rutherglen    LAB
# 53           Stirling and Strathallan    CON
# 54  West Aberdeenshire and Kincardine    LAB
# 55                West Dunbartonshire    LAB
#
# [650 rows x 2 columns]
#
# Year: 2015
#                          Constituency Winner
# 0                    Aberafan Maesteg    LAB
# 1                           Aldershot    CON
# 2                 Aldridge-Brownhills    CON
# 3            Altrincham and Sale West    CON
# 4                    Alyn and Deeside    LAB
# ..                                ...    ...
# 51            Perth and Kinross-shire    SNP
# 52                         Rutherglen    SNP
# 53           Stirling and Strathallan    SNP
# 54  West Aberdeenshire and Kincardine    SNP
# 55                West Dunbartonshire    SNP
#
# [650 rows x 2 columns]
#
# Year: 2017
#                          Constituency Winner
# 0                    Aberafan Maesteg    LAB
# 1                           Aldershot    CON
# 2                 Aldridge-Brownhills    CON
# 3            Altrincham and Sale West    CON
# 4                    Alyn and Deeside    CON
# ..                                ...    ...
# 51            Perth and Kinross-shire    SNP
# 52                         Rutherglen    SNP
# 53           Stirling and Strathallan    CON
# 54  West Aberdeenshire and Kincardine    SNP
# 55                West Dunbartonshire    SNP
#
# [650 rows x 2 columns]
#
# Year: 2019
#                          Constituency Winner
# 0                    Aberafan Maesteg    LAB
# 1                           Aldershot    CON
# 2                 Aldridge-Brownhills    CON
# 3            Altrincham and Sale West    CON
# 4                    Alyn and Deeside    LAB
# ..                                ...    ...
# 51            Perth and Kinross-shire    GRE
# 52                         Rutherglen    GRE
# 53           Stirling and Strathallan    CON
# 54  West Aberdeenshire and Kincardine    GRE
# 55                West Dunbartonshire    GRE
#
# [650 rows x 2 columns]
#
# Year: 2024
#                          Constituency Winner
# 0                    Aberafan Maesteg    LAB
# 1                           Aldershot    CON
# 2                 Aldridge-Brownhills    CON
# 3            Altrincham and Sale West    LAB
# 4                    Alyn and Deeside    LAB
# ..                                ...    ...
# 51            Perth and Kinross-shire    SNP
# 52                         Rutherglen    LAB
# 53           Stirling and Strathallan    CON
# 54  West Aberdeenshire and Kincardine    LAB
# 55                West Dunbartonshire    LAB
#
# [650 rows x 2 columns]
#
# Constituency Winners for model: polls_model_df
# Year: 2010
#                          Constituency Winner
# 0                    Aberafan Maesteg    LAB
# 1                           Aldershot    CON
# 2                 Aldridge-Brownhills    CON
# 3            Altrincham and Sale West    CON
# 4                    Alyn and Deeside    LAB
# ..                                ...    ...
# 51            Perth and Kinross-shire    SNP
# 52                         Rutherglen    LAB
# 53           Stirling and Strathallan    CON
# 54  West Aberdeenshire and Kincardine    LAB
# 55                West Dunbartonshire    LAB
#
# [650 rows x 2 columns]
#
# Year: 2015
#                          Constituency Winner
# 0                    Aberafan Maesteg    LAB
# 1                           Aldershot    CON
# 2                 Aldridge-Brownhills    CON
# 3            Altrincham and Sale West    CON
# 4                    Alyn and Deeside    LAB
# ..                                ...    ...
# 51            Perth and Kinross-shire    SNP
# 52                         Rutherglen    SNP
# 53           Stirling and Strathallan    SNP
# 54  West Aberdeenshire and Kincardine    SNP
# 55                West Dunbartonshire    SNP
#
# [650 rows x 2 columns]
#
# Year: 2017
#                          Constituency Winner
# 0                    Aberafan Maesteg    LAB
# 1                           Aldershot    CON
# 2                 Aldridge-Brownhills    CON
# 3            Altrincham and Sale West    CON
# 4                    Alyn and Deeside    CON
# ..                                ...    ...
# 51            Perth and Kinross-shire    SNP
# 52                         Rutherglen    SNP
# 53           Stirling and Strathallan    CON
# 54  West Aberdeenshire and Kincardine    SNP
# 55                West Dunbartonshire    SNP
#
# [650 rows x 2 columns]
#
# Year: 2019
#                          Constituency Winner
# 0                    Aberafan Maesteg    LAB
# 1                           Aldershot    CON
# 2                 Aldridge-Brownhills    CON
# 3            Altrincham and Sale West    CON
# 4                    Alyn and Deeside    LAB
# ..                                ...    ...
# 51            Perth and Kinross-shire    GRE
# 52                         Rutherglen    GRE
# 53           Stirling and Strathallan    CON
# 54  West Aberdeenshire and Kincardine    GRE
# 55                West Dunbartonshire    GRE
#
# [650 rows x 2 columns]
#
# Year: 2024
#                          Constituency Winner
# 0                    Aberafan Maesteg    LAB
# 1                           Aldershot    CON
# 2                 Aldridge-Brownhills    CON
# 3            Altrincham and Sale West    LAB
# 4                    Alyn and Deeside    LAB
# ..                                ...    ...
# 51            Perth and Kinross-shire    SNP
# 52                         Rutherglen    LAB
# 53           Stirling and Strathallan    CON
# 54  West Aberdeenshire and Kincardine    LAB
# 55                West Dunbartonshire    LAB
#
# [650 rows x 2 columns]
#
# Constituency Winners for model: polls_eco_df
# Year: 2010
#                          Constituency Winner
# 0                    Aberafan Maesteg    LAB
# 1                           Aldershot    CON
# 2                 Aldridge-Brownhills    CON
# 3            Altrincham and Sale West    CON
# 4                    Alyn and Deeside    LAB
# ..                                ...    ...
# 51            Perth and Kinross-shire    SNP
# 52                         Rutherglen    LAB
# 53           Stirling and Strathallan    CON
# 54  West Aberdeenshire and Kincardine    LAB
# 55                West Dunbartonshire    LAB
#
# [650 rows x 2 columns]
#
# Year: 2015
#                          Constituency Winner
# 0                    Aberafan Maesteg    LAB
# 1                           Aldershot    CON
# 2                 Aldridge-Brownhills    CON
# 3            Altrincham and Sale West    CON
# 4                    Alyn and Deeside    LAB
# ..                                ...    ...
# 51            Perth and Kinross-shire    SNP
# 52                         Rutherglen    SNP
# 53           Stirling and Strathallan    SNP
# 54  West Aberdeenshire and Kincardine    SNP
# 55                West Dunbartonshire    SNP
#
# [650 rows x 2 columns]
#
# Year: 2017
#                          Constituency Winner
# 0                    Aberafan Maesteg    LAB
# 1                           Aldershot    CON
# 2                 Aldridge-Brownhills    CON
# 3            Altrincham and Sale West    CON
# 4                    Alyn and Deeside    CON
# ..                                ...    ...
# 51            Perth and Kinross-shire    SNP
# 52                         Rutherglen    SNP
# 53           Stirling and Strathallan    CON
# 54  West Aberdeenshire and Kincardine    SNP
# 55                West Dunbartonshire    SNP
#
# [650 rows x 2 columns]
#
# Year: 2019
#                          Constituency Winner
# 0                    Aberafan Maesteg    LAB
# 1                           Aldershot    CON
# 2                 Aldridge-Brownhills    CON
# 3            Altrincham and Sale West    CON
# 4                    Alyn and Deeside    LAB
# ..                                ...    ...
# 51            Perth and Kinross-shire    GRE
# 52                         Rutherglen    GRE
# 53           Stirling and Strathallan    CON
# 54  West Aberdeenshire and Kincardine    GRE
# 55                West Dunbartonshire    GRE
#
# [650 rows x 2 columns]
#
# Year: 2024
#                          Constituency Winner
# 0                    Aberafan Maesteg    LAB
# 1                           Aldershot    CON
# 2                 Aldridge-Brownhills    CON
# 3            Altrincham and Sale West    CON
# 4                    Alyn and Deeside    LAB
# ..                                ...    ...
# 51            Perth and Kinross-shire    SNP
# 52                         Rutherglen    LAB
# 53           Stirling and Strathallan    CON
# 54  West Aberdeenshire and Kincardine    LAB
# 55                West Dunbartonshire    LAB
#
# [650 rows x 2 columns]
#
# Constituency Winners for model: polls_alt_df
# Year: 2010
#                          Constituency Winner
# 0                    Aberafan Maesteg    LAB
# 1                           Aldershot    CON
# 2                 Aldridge-Brownhills    CON
# 3            Altrincham and Sale West    CON
# 4                    Alyn and Deeside    LAB
# ..                                ...    ...
# 51            Perth and Kinross-shire    SNP
# 52                         Rutherglen    LAB
# 53           Stirling and Strathallan    CON
# 54  West Aberdeenshire and Kincardine    LAB
# 55                West Dunbartonshire    LAB
#
# [650 rows x 2 columns]
#
# Year: 2015
#                          Constituency Winner
# 0                    Aberafan Maesteg    LAB
# 1                           Aldershot    CON
# 2                 Aldridge-Brownhills    CON
# 3            Altrincham and Sale West    CON
# 4                    Alyn and Deeside    LAB
# ..                                ...    ...
# 51            Perth and Kinross-shire    SNP
# 52                         Rutherglen    SNP
# 53           Stirling and Strathallan    SNP
# 54  West Aberdeenshire and Kincardine    SNP
# 55                West Dunbartonshire    SNP
#
# [650 rows x 2 columns]
#
# Year: 2017
#                          Constituency Winner
# 0                    Aberafan Maesteg    LAB
# 1                           Aldershot    CON
# 2                 Aldridge-Brownhills    CON
# 3            Altrincham and Sale West    CON
# 4                    Alyn and Deeside    CON
# ..                                ...    ...
# 51            Perth and Kinross-shire    SNP
# 52                         Rutherglen    SNP
# 53           Stirling and Strathallan    CON
# 54  West Aberdeenshire and Kincardine    SNP
# 55                West Dunbartonshire    SNP
#
# [650 rows x 2 columns]
#
# Year: 2019
#                          Constituency Winner
# 0                    Aberafan Maesteg    LAB
# 1                           Aldershot    CON
# 2                 Aldridge-Brownhills    CON
# 3            Altrincham and Sale West    CON
# 4                    Alyn and Deeside    LAB
# ..                                ...    ...
# 51            Perth and Kinross-shire    GRE
# 52                         Rutherglen    GRE
# 53           Stirling and Strathallan    CON
# 54  West Aberdeenshire and Kincardine    GRE
# 55                West Dunbartonshire    GRE
#
# [650 rows x 2 columns]
#
# Year: 2024
#                          Constituency Winner
# 0                    Aberafan Maesteg    LAB
# 1                           Aldershot    CON
# 2                 Aldridge-Brownhills    CON
# 3            Altrincham and Sale West    CON
# 4                    Alyn and Deeside    LAB
# ..                                ...    ...
# 51            Perth and Kinross-shire    SNP
# 52                         Rutherglen    LAB
# 53           Stirling and Strathallan    CON
# 54  West Aberdeenshire and Kincardine    LAB
# 55                West Dunbartonshire    LAB
#
# [650 rows x 2 columns]
#
# Constituency Winners for model: polls_eco_alt_df
# Year: 2010
#                          Constituency Winner
# 0                    Aberafan Maesteg    LAB
# 1                           Aldershot    CON
# 2                 Aldridge-Brownhills    CON
# 3            Altrincham and Sale West    CON
# 4                    Alyn and Deeside    LAB
# ..                                ...    ...
# 51            Perth and Kinross-shire    SNP
# 52                         Rutherglen    LAB
# 53           Stirling and Strathallan    CON
# 54  West Aberdeenshire and Kincardine    LAB
# 55                West Dunbartonshire    LAB
#
# [650 rows x 2 columns]
#
# Year: 2015
#                          Constituency Winner
# 0                    Aberafan Maesteg    LAB
# 1                           Aldershot    CON
# 2                 Aldridge-Brownhills    CON
# 3            Altrincham and Sale West    CON
# 4                    Alyn and Deeside    LAB
# ..                                ...    ...
# 51            Perth and Kinross-shire    SNP
# 52                         Rutherglen    SNP
# 53           Stirling and Strathallan    SNP
# 54  West Aberdeenshire and Kincardine    SNP
# 55                West Dunbartonshire    SNP
#
# [650 rows x 2 columns]
#
# Year: 2017
#                          Constituency Winner
# 0                    Aberafan Maesteg    LAB
# 1                           Aldershot    CON
# 2                 Aldridge-Brownhills    CON
# 3            Altrincham and Sale West    CON
# 4                    Alyn and Deeside    CON
# ..                                ...    ...
# 51            Perth and Kinross-shire    SNP
# 52                         Rutherglen    SNP
# 53           Stirling and Strathallan    CON
# 54  West Aberdeenshire and Kincardine    SNP
# 55                West Dunbartonshire    SNP
#
# [650 rows x 2 columns]
#
# Year: 2019
#                          Constituency Winner
# 0                    Aberafan Maesteg    LAB
# 1                           Aldershot    CON
# 2                 Aldridge-Brownhills    CON
# 3            Altrincham and Sale West    CON
# 4                    Alyn and Deeside    LAB
# ..                                ...    ...
# 51            Perth and Kinross-shire    GRE
# 52                         Rutherglen    GRE
# 53           Stirling and Strathallan    CON
# 54  West Aberdeenshire and Kincardine    GRE
# 55                West Dunbartonshire    GRE
#
# [650 rows x 2 columns]
#
# Year: 2024
#                          Constituency Winner
# 0                    Aberafan Maesteg    LAB
# 1                           Aldershot    CON
# 2                 Aldridge-Brownhills    CON
# 3            Altrincham and Sale West    LAB
# 4                    Alyn and Deeside    LAB
# ..                                ...    ...
# 51            Perth and Kinross-shire    SNP
# 52                         Rutherglen    LAB
# 53           Stirling and Strathallan    CON
# 54  West Aberdeenshire and Kincardine    LAB
# 55                West Dunbartonshire    LAB
#
# [650 rows x 2 columns]

# %%
import pandas as pd

# Load predictions from csvs
uk_df_dct = {}
uk_df_dct['actuals_df'] = pd.read_excel('../processed_data/election_forecast_tracker.xlsx', sheet_name='actuals', index_col=0)
uk_df_dct['polls_avg_df'] = pd.read_excel('../processed_data/election_forecast_tracker.xlsx', sheet_name='polls_average', index_col=0)
uk_df_dct['polls_model_df'] = pd.read_excel('../processed_data/election_forecast_tracker.xlsx', sheet_name='polls_model', index_col=0)
uk_df_dct['polls_eco_df'] = pd.read_excel('../processed_data/election_forecast_tracker.xlsx', sheet_name='polls_eco', index_col=0)
uk_df_dct['polls_alt_df'] = pd.read_excel('../processed_data/election_forecast_tracker.xlsx', sheet_name='polls_alt', index_col=0)
uk_df_dct['polls_eco_alt_df'] = pd.read_excel('../processed_data/election_forecast_tracker.xlsx', sheet_name='polls_eco_alt', index_col=0)

# Load Scottish forecast data
scotland_df = pd.read_excel('../processed_data/election_forecast_tracker.xlsx', sheet_name='scotland', index_col=0)

# Loading hex constituency mapping
hex_map = pd.read_excel('../processed_data/election_forecast_tracker.xlsx', sheet_name='hex_codes', index_col=0)
constituency_map = pd.read_excel('../processed_data/election_forecast_tracker.xlsx', sheet_name='constituency_coords', index_col=0)

# Define the forecast models
forecast_models = uk_df_dct.copy()

# Import the test bias data
test_bias = pd.read_csv('../processed_data/last_bias.csv', index_col=0)

# Function to adjust SNP bias scores
def adjust_snp_bias(bias_dataframe, years, factor):
    for year in years:
        snp_bias_column = f"SNP_Bias_Score"
        if snp_bias_column in bias_dataframe.columns:
            bias_dataframe.loc[:, snp_bias_column] *= factor
    return bias_dataframe

# Adjust SNP bias for the last three elections
years_to_adjust = [2024]
snp_adjustment_factor = 5
test_bias = adjust_snp_bias(test_bias, years_to_adjust, snp_adjustment_factor)

def calculate_predicted_vote_share(forecast, bias_scores):
    predicted_vote_share = {}
    for party, forecast_share in forecast.items():
        bias_score = bias_scores.get(f"{party}_Bias_Score", 0)
        predicted_vote_share[party] = forecast_share + bias_score
    return predicted_vote_share
def determine_winner(predicted_vote_share):
    return max(predicted_vote_share, key=predicted_vote_share.get)
def determine_winners(forecast, bias_dataframe):
    winners = []
    for index, row in bias_dataframe.iterrows():
        predicted_vote_share = calculate_predicted_vote_share(forecast, row)
        winner = determine_winner(predicted_vote_share)
        winners.append({'Constituency': index, 'Winner': winner})
    return pd.DataFrame(winners)

# Separate Scottish and non-Scottish constituencies in the bias data
scottish_bias = test_bias[test_bias['Scotland'] == True]
uk_test_bias = test_bias[test_bias['Scotland'] == False]

# Container for results
total_constituencies_results = {}
constituency_winners_results = {}

# Loop through each model and each forecast year
for model_name, forecast_df in forecast_models.items():
    model_results = {}
    constituency_winners = {}
    for year in forecast_df.columns:
        forecast = forecast_df[year].dropna().to_dict()
        scotland_forecast = scotland_df[year].dropna().to_dict()

        # Determine winners for UK (excluding Scotland)
        uk_winners_df = determine_winners(forecast, uk_test_bias)
        uk_total_constituencies = uk_winners_df['Winner'].value_counts().reset_index()
        uk_total_constituencies.columns = ['Party', 'Total_Constituencies']

        # Determine winners for Scotland
        scotland_winners_df = determine_winners(scotland_forecast, scottish_bias)
        scotland_total_constituencies = scotland_winners_df['Winner'].value_counts().reset_index()
        scotland_total_constituencies.columns = ['Party', 'Total_Constituencies']

        # Concatenate the results
        total_constituencies = pd.concat([uk_total_constituencies, scotland_total_constituencies]).groupby('Party').sum().reset_index()

        # Add the original vote share to the table
        total_constituencies['Vote_Share'] = total_constituencies['Party'].map(forecast_df[year])

        # Concatenate the constituency winners
        winners_df = pd.concat([uk_winners_df, scotland_winners_df])
        winners_df = pd.merge(winners_df,hex_map,how='left',left_on='Winner',right_on='party_code')
        winners_df = pd.merge(winners_df,constituency_map,how='left',left_on='Constituency',right_on='constituency_name')
        model_results[year] = total_constituencies
        constituency_winners[year] = winners_df
    total_constituencies_results[model_name] = model_results
    constituency_winners_results[model_name] = constituency_winners

# %%
winners_df
# Out:
#                           Constituency Winner elected_mp_party  \
# 0                     Aberafan Maesteg    LAB              Lab
# 1                            Aldershot    CON              Con
# 2                  Aldridge-Brownhills    CON              Con
# 3             Altrincham and Sale West    LAB              Lab
# 4                     Alyn and Deeside    LAB              Lab
# ..                                 ...    ...              ...
# 645            Perth and Kinross-shire    SNP              SNP
# 646                         Rutherglen    LAB              Lab
# 647           Stirling and Strathallan    SNP              SNP
# 648  West Aberdeenshire and Kincardine    SNP              SNP
# 649                West Dunbartonshire    LAB              Lab
#
#     elected_mp_party_name    color                  constituency_name  \
# 0                  Labour  #dd0018                   Aberafan Maesteg
# 1            Conservative  #005af0                          Aldershot
# 2            Conservative  #005af0                Aldridge-Brownhills
# 3                  Labour  #dd0018           Altrincham and Sale West
# 4                  Labour  #dd0018                   Alyn and Deeside
# ..                    ...      ...                                ...
# 645                   SNP  #fff293            Perth and Kinross-shire
# 646                Labour  #dd0018                         Rutherglen
# 647                   SNP  #fff293           Stirling and Strathallan
# 648                   SNP  #fff293  West Aberdeenshire and Kincardine
# 649                Labour  #dd0018                West Dunbartonshire
#
#      coord_one  coord_two
# 0          -36         46
# 1          -40         56
# 2          -30         56
# 3          -25         52
# 4          -29         49
# ..         ...        ...
# 645         -5         51
# 646        -12         49
# 647         -6         49
# 648         -4         51
# 649         -7         48
#
# [650 rows x 8 columns]

# %%
# Create an Excel writer
with pd.ExcelWriter('election_results.xlsx') as writer:

    # Write total constituencies results to Excel
    for model_name, results in total_constituencies_results.items():
        for year, df in results.items():
            sheet_name = f"{model_name}_{year}_total"
            df.to_excel(writer, sheet_name=sheet_name, index=False)

    # Write constituency winners results to Excel
    for model_name, results in constituency_winners_results.items():
        for year, df in results.items():
            sheet_name = f"{model_name}_{year}_winners"
            df.to_excel(writer, sheet_name=sheet_name, index=False)

# Display the results for verification
for model_name, results in total_constituencies_results.items():
    print(f"Results for model: {model_name}")
    for year, df in results.items():
        print(f"Year: {year}")
        print(df)
        print()

for model_name, results in constituency_winners_results.items():
    print(f"Constituency Winners for model: {model_name}")
    for year, df in results.items():
        print(f"Year: {year}")
        print(df)
        print()
# Out:
# Results for model: actuals_df
# Year: 2010
#   Party  Total_Constituencies  Vote_Share
# 0   CON                   320        36.2
# 1   GRE                     1         0.7
# 2   LAB                   257        29.2
# 3   LIB                    40        23.5
# 4   OTH                    19        10.8
# 5   PLC                     3         0.6
# 6   SNP                    10         3.4
#
# Year: 2015
#   Party  Total_Constituencies  Vote_Share
# 0   CON                   339        36.9
# 1   GRE                     1         3.8
# 2   LAB                   230        30.4
# 3   LIB                    10         7.9
# 4   OTH                    19         3.1
# 5   PLC                     4         0.6
# 6   SNP                    47         4.7
#
# Year: 2017
#   Party  Total_Constituencies  Vote_Share
# 0   CON                   328        42.4
# 1   GRE                     1         1.6
# 2   LAB                   248        40.0
# 3   LIB                     7         7.4
# 4   OTH                    19         3.3
# 5   PLC                     4         0.5
# 6   SNP                    43         3.0
#
# Year: 2019
#   Party  Total_Constituencies  Vote_Share
# 0   CON                   366        43.8
# 1   GRE                     1         3.5
# 2   LAB                   204        32.7
# 3   LIB                    10        11.6
# 4   OTH                    19         3.1
# 5   PLC                     4         0.5
# 6   SNP                    46         3.8
#
# Year: 2024
#        Party  Total_Constituencies  Vote_Share
# 0  BRX + UKI                    16        12.5
# 1        CON                   147        23.0
# 2        GRE                     1         5.8
# 3        LAB                   445        44.1
# 4        LIB                    29         9.5
# 5        SNP                    12         NaN
#
# Results for model: polls_avg_df
# Year: 2010
#   Party  Total_Constituencies  Vote_Share
# 0   CON                   330        37.6
# 1   GRE                     1         0.0
# 2   LAB                   257        30.5
# 3   LIB                    30        19.5
# 4   OTH                    19        12.3
# 5   PLC                     3         0.0
# 6   SNP                    10         0.0
#
# Year: 2015
#   Party  Total_Constituencies  Vote_Share
# 0   CON                   295        33.5
# 1   GRE                     1         5.3
# 2   LAB                   269        34.0
# 3   LIB                    15         8.0
# 4   OTH                    19         5.5
# 5   PLC                     4         0.0
# 6   SNP                    47         0.0
#
# Year: 2017
#   Party  Total_Constituencies  Vote_Share
# 0   CON                   413        46.7
# 1   GRE                     1         2.9
# 2   LAB                   163        28.5
# 3   LIB                     7         9.7
# 4   OTH                    19         1.5
# 5   PLC                     4         0.6
# 6   SNP                    43         4.2
#
# Year: 2019
#   Party  Total_Constituencies  Vote_Share
# 0   CON                   361        39.6
# 1   GRE                     1         3.9
# 2   LAB                   198        27.8
# 3   LIB                    21        15.8
# 4   OTH                    19         1.1
# 5   PLC                     4         0.5
# 6   SNP                    46         3.7
#
# Year: 2024
#   Party  Total_Constituencies  Vote_Share
# 0   CON                   146        23.2
# 1   GRE                     1         5.7
# 2   LAB                   440        44.6
# 3   LIB                    27         9.4
# 4   OTH                    19         1.9
# 5   PLC                     4         0.7
# 6   SNP                    13         2.7
#
# Results for model: polls_model_df
# Year: 2010
#   Party  Total_Constituencies  Vote_Share
# 0   CON                   323        37.0
# 1   GRE                     1         0.9
# 2   LAB                   263        31.0
# 3   LIB                    31        19.7
# 4   OTH                    19        11.5
# 5   PLC                     3         0.6
# 6   SNP                    10         3.7
#
# Year: 2015
#   Party  Total_Constituencies  Vote_Share
# 0   CON                   295        33.5
# 1   GRE                     1         5.3
# 2   LAB                   269        34.0
# 3   LIB                    15         8.0
# 4   OTH                    19         5.5
# 5   PLC                     4         0.5
# 6   SNP                    47         4.0
#
# Year: 2017
#   Party  Total_Constituencies  Vote_Share
# 0   CON                   413        46.7
# 1   GRE                     1         1.7
# 2   LAB                   163        28.4
# 3   LIB                     7         9.7
# 4   OTH                    19         1.5
# 5   PLC                     4         0.6
# 6   SNP                    43         4.2
#
# Year: 2019
#   Party  Total_Constituencies  Vote_Share
# 0   CON                   353        40.4
# 1   GRE                     1         2.5
# 2   LAB                   210        31.3
# 3   LIB                    18        15.1
# 4   OTH                    19         1.3
# 5   PLC                     3         0.5
# 6   SNP                    46         3.5
#
# Year: 2024
#   Party  Total_Constituencies  Vote_Share
# 0   CON                   182       24.40
# 1   GRE                     1        5.30
# 2   LAB                   405       41.10
# 3   LIB                    26        9.10
# 4   OTH                    19        2.30
# 5   PLC                     4        0.66
# 6   SNP                    13        2.90
#
# Results for model: polls_eco_df
# Year: 2010
#   Party  Total_Constituencies  Vote_Share
# 0   CON                   323        37.1
# 1   GRE                     1         0.9
# 2   LAB                   263        31.0
# 3   LIB                    31        19.7
# 4   OTH                    19        11.5
# 5   PLC                     3         0.0
# 6   SNP                    10         1.9
#
# Year: 2015
#   Party  Total_Constituencies  Vote_Share
# 0   CON                   293        33.4
# 1   GRE                     1         5.3
# 2   LAB                   270        34.0
# 3   LIB                    16         9.0
# 4   OTH                    19         5.5
# 5   PLC                     4         0.5
# 6   SNP                    47         4.0
#
# Year: 2017
#   Party  Total_Constituencies  Vote_Share
# 0   CON                   413        46.7
# 1   GRE                     1         2.9
# 2   LAB                   163        28.5
# 3   LIB                     7         9.7
# 4   OTH                    19         1.2
# 5   PLC                     4         0.5
# 6   SNP                    43         3.3
#
# Year: 2019
#   Party  Total_Constituencies  Vote_Share
# 0   CON                   350        40.7
# 1   GRE                     1         3.6
# 2   LAB                   213        31.9
# 3   LIB                    18        15.2
# 4   OTH                    19         1.4
# 5   PLC                     3         0.5
# 6   SNP                    46         3.5
#
# Year: 2024
#   Party  Total_Constituencies  Vote_Share
# 0   CON                   229       31.00
# 1   GRE                     1        4.80
# 2   LAB                   367       44.00
# 3   LIB                    17        9.10
# 4   OTH                    19        2.50
# 5   PLC                     4        0.46
# 6   SNP                    13        2.80
#
# Results for model: polls_alt_df
# Year: 2010
#   Party  Total_Constituencies  Vote_Share
# 0   CON                   295        34.4
# 1   GRE                     1         0.9
# 2   LAB                   277        31.7
# 3   LIB                    45        22.6
# 4   OTH                    19         5.4
# 5   PLC                     3         0.6
# 6   SNP                    10         3.8
#
# Year: 2015
#   Party  Total_Constituencies  Vote_Share
# 0   CON                   296        33.6
# 1   GRE                     1         5.3
# 2   LAB                   268        33.7
# 3   LIB                    15         8.0
# 4   OTH                    19         5.4
# 5   PLC                     4         0.6
# 6   SNP                    47         4.2
#
# Year: 2017
#   Party  Total_Constituencies  Vote_Share
# 0   CON                   413        46.7
# 1   GRE                     1         2.9
# 2   LAB                   163        28.5
# 3   LIB                     7         9.7
# 4   OTH                    19         1.1
# 5   PLC                     4         0.6
# 6   SNP                    43         3.3
#
# Year: 2019
#   Party  Total_Constituencies  Vote_Share
# 0   CON                   341        40.2
# 1   GRE                     1         3.7
# 2   LAB                   222        32.7
# 3   LIB                    18        14.3
# 4   OTH                    19         1.1
# 5   PLC                     3         0.3
# 6   SNP                    46         3.5
#
# Year: 2024
#   Party  Total_Constituencies  Vote_Share
# 0   CON                   244       29.70
# 1   GRE                     1        5.30
# 2   LAB                   350       39.40
# 3   LIB                    19        9.70
# 4   OTH                    19        2.50
# 5   PLC                     4        0.45
# 6   SNP                    13        2.90
#
# Results for model: polls_eco_alt_df
# Year: 2010
#   Party  Total_Constituencies  Vote_Share
# 0   CON                   300        35.2
# 1   GRE                     1         0.4
# 2   LAB                   279        32.7
# 3   LIB                    38        20.7
# 4   OTH                    19         8.9
# 5   PLC                     3         0.3
# 6   SNP                    10         1.9
#
# Year: 2015
#   Party  Total_Constituencies  Vote_Share
# 0   CON                   291        33.3
# 1   GRE                     1         5.2
# 2   LAB                   273        34.2
# 3   LIB                    15         7.9
# 4   OTH                    19         5.4
# 5   PLC                     4         0.5
# 6   SNP                    47         1.8
#
# Year: 2017
#   Party  Total_Constituencies  Vote_Share
# 0   CON                   413        46.7
# 1   GRE                     1         1.9
# 2   LAB                   163        28.6
# 3   LIB                     7         9.7
# 4   OTH                    19         1.2
# 5   PLC                     4         0.7
# 6   SNP                    43         3.3
#
# Year: 2019
#   Party  Total_Constituencies  Vote_Share
# 0   CON                   336        40.0
# 1   GRE                     1         3.9
# 2   LAB                   226        33.5
# 3   LIB                    19        15.8
# 4   OTH                    19         1.0
# 5   PLC                     3         0.5
# 6   SNP                    46         3.8
#
# Year: 2024
#   Party  Total_Constituencies  Vote_Share
# 0   CON                   218       28.10
# 1   GRE                     1        5.20
# 2   LAB                   375       42.00
# 3   LIB                    20        9.10
# 4   OTH                    19        2.40
# 5   PLC                     4        0.46
# 6   SNP                    13        2.90
#
# Constituency Winners for model: actuals_df
# Year: 2010
#                           Constituency Winner elected_mp_party  \
# 0                     Aberafan Maesteg    LAB              Lab
# 1                            Aldershot    CON              Con
# 2                  Aldridge-Brownhills    CON              Con
# 3             Altrincham and Sale West    CON              Con
# 4                     Alyn and Deeside    LAB              Lab
# ..                                 ...    ...              ...
# 645            Perth and Kinross-shire    SNP              SNP
# 646                         Rutherglen    LAB              Lab
# 647           Stirling and Strathallan    CON              Con
# 648  West Aberdeenshire and Kincardine    SNP              SNP
# 649                West Dunbartonshire    LAB              Lab
#
#     elected_mp_party_name    color                  constituency_name  \
# 0                  Labour  #dd0018                   Aberafan Maesteg
# 1            Conservative  #005af0                          Aldershot
# 2            Conservative  #005af0                Aldridge-Brownhills
# 3            Conservative  #005af0           Altrincham and Sale West
# 4                  Labour  #dd0018                   Alyn and Deeside
# ..                    ...      ...                                ...
# 645                   SNP  #fff293            Perth and Kinross-shire
# 646                Labour  #dd0018                         Rutherglen
# 647          Conservative  #005af0           Stirling and Strathallan
# 648                   SNP  #fff293  West Aberdeenshire and Kincardine
# 649                Labour  #dd0018                West Dunbartonshire
#
#      coord_one  coord_two
# 0          -36         46
# 1          -40         56
# 2          -30         56
# 3          -25         52
# 4          -29         49
# ..         ...        ...
# 645         -5         51
# 646        -12         49
# 647         -6         49
# 648         -4         51
# 649         -7         48
#
# [650 rows x 8 columns]
#
# Year: 2015
#                           Constituency Winner elected_mp_party  \
# 0                     Aberafan Maesteg    LAB              Lab
# 1                            Aldershot    CON              Con
# 2                  Aldridge-Brownhills    CON              Con
# 3             Altrincham and Sale West    CON              Con
# 4                     Alyn and Deeside    LAB              Lab
# ..                                 ...    ...              ...
# 645            Perth and Kinross-shire    SNP              SNP
# 646                         Rutherglen    SNP              SNP
# 647           Stirling and Strathallan    SNP              SNP
# 648  West Aberdeenshire and Kincardine    SNP              SNP
# 649                West Dunbartonshire    SNP              SNP
#
#     elected_mp_party_name    color                  constituency_name  \
# 0                  Labour  #dd0018                   Aberafan Maesteg
# 1            Conservative  #005af0                          Aldershot
# 2            Conservative  #005af0                Aldridge-Brownhills
# 3            Conservative  #005af0           Altrincham and Sale West
# 4                  Labour  #dd0018                   Alyn and Deeside
# ..                    ...      ...                                ...
# 645                   SNP  #fff293            Perth and Kinross-shire
# 646                   SNP  #fff293                         Rutherglen
# 647                   SNP  #fff293           Stirling and Strathallan
# 648                   SNP  #fff293  West Aberdeenshire and Kincardine
# 649                   SNP  #fff293                West Dunbartonshire
#
#      coord_one  coord_two
# 0          -36         46
# 1          -40         56
# 2          -30         56
# 3          -25         52
# 4          -29         49
# ..         ...        ...
# 645         -5         51
# 646        -12         49
# 647         -6         49
# 648         -4         51
# 649         -7         48
#
# [650 rows x 8 columns]
#
# Year: 2017
#                           Constituency Winner elected_mp_party  \
# 0                     Aberafan Maesteg    LAB              Lab
# 1                            Aldershot    CON              Con
# 2                  Aldridge-Brownhills    CON              Con
# 3             Altrincham and Sale West    CON              Con
# 4                     Alyn and Deeside    LAB              Lab
# ..                                 ...    ...              ...
# 645            Perth and Kinross-shire    SNP              SNP
# 646                         Rutherglen    SNP              SNP
# 647           Stirling and Strathallan    SNP              SNP
# 648  West Aberdeenshire and Kincardine    SNP              SNP
# 649                West Dunbartonshire    SNP              SNP
#
#     elected_mp_party_name    color                  constituency_name  \
# 0                  Labour  #dd0018                   Aberafan Maesteg
# 1            Conservative  #005af0                          Aldershot
# 2            Conservative  #005af0                Aldridge-Brownhills
# 3            Conservative  #005af0           Altrincham and Sale West
# 4                  Labour  #dd0018                   Alyn and Deeside
# ..                    ...      ...                                ...
# 645                   SNP  #fff293            Perth and Kinross-shire
# 646                   SNP  #fff293                         Rutherglen
# 647                   SNP  #fff293           Stirling and Strathallan
# 648                   SNP  #fff293  West Aberdeenshire and Kincardine
# 649                   SNP  #fff293                West Dunbartonshire
#
#      coord_one  coord_two
# 0          -36         46
# 1          -40         56
# 2          -30         56
# 3          -25         52
# 4          -29         49
# ..         ...        ...
# 645         -5         51
# 646        -12         49
# 647         -6         49
# 648         -4         51
# 649         -7         48
#
# [650 rows x 8 columns]
#
# Year: 2019
#                           Constituency Winner elected_mp_party  \
# 0                     Aberafan Maesteg    LAB              Lab
# 1                            Aldershot    CON              Con
# 2                  Aldridge-Brownhills    CON              Con
# 3             Altrincham and Sale West    CON              Con
# 4                     Alyn and Deeside    LAB              Lab
# ..                                 ...    ...              ...
# 645            Perth and Kinross-shire    SNP              SNP
# 646                         Rutherglen    SNP              SNP
# 647           Stirling and Strathallan    SNP              SNP
# 648  West Aberdeenshire and Kincardine    SNP              SNP
# 649                West Dunbartonshire    SNP              SNP
#
#     elected_mp_party_name    color                  constituency_name  \
# 0                  Labour  #dd0018                   Aberafan Maesteg
# 1            Conservative  #005af0                          Aldershot
# 2            Conservative  #005af0                Aldridge-Brownhills
# 3            Conservative  #005af0           Altrincham and Sale West
# 4                  Labour  #dd0018                   Alyn and Deeside
# ..                    ...      ...                                ...
# 645                   SNP  #fff293            Perth and Kinross-shire
# 646                   SNP  #fff293                         Rutherglen
# 647                   SNP  #fff293           Stirling and Strathallan
# 648                   SNP  #fff293  West Aberdeenshire and Kincardine
# 649                   SNP  #fff293                West Dunbartonshire
#
#      coord_one  coord_two
# 0          -36         46
# 1          -40         56
# 2          -30         56
# 3          -25         52
# 4          -29         49
# ..         ...        ...
# 645         -5         51
# 646        -12         49
# 647         -6         49
# 648         -4         51
# 649         -7         48
#
# [650 rows x 8 columns]
#
# Year: 2024
#                           Constituency Winner elected_mp_party  \
# 0                     Aberafan Maesteg    LAB              Lab
# 1                            Aldershot    CON              Con
# 2                  Aldridge-Brownhills    CON              Con
# 3             Altrincham and Sale West    LAB              Lab
# 4                     Alyn and Deeside    LAB              Lab
# ..                                 ...    ...              ...
# 645            Perth and Kinross-shire    SNP              SNP
# 646                         Rutherglen    LAB              Lab
# 647           Stirling and Strathallan    SNP              SNP
# 648  West Aberdeenshire and Kincardine    SNP              SNP
# 649                West Dunbartonshire    LAB              Lab
#
#     elected_mp_party_name    color                  constituency_name  \
# 0                  Labour  #dd0018                   Aberafan Maesteg
# 1            Conservative  #005af0                          Aldershot
# 2            Conservative  #005af0                Aldridge-Brownhills
# 3                  Labour  #dd0018           Altrincham and Sale West
# 4                  Labour  #dd0018                   Alyn and Deeside
# ..                    ...      ...                                ...
# 645                   SNP  #fff293            Perth and Kinross-shire
# 646                Labour  #dd0018                         Rutherglen
# 647                   SNP  #fff293           Stirling and Strathallan
# 648                   SNP  #fff293  West Aberdeenshire and Kincardine
# 649                Labour  #dd0018                West Dunbartonshire
#
#      coord_one  coord_two
# 0          -36         46
# 1          -40         56
# 2          -30         56
# 3          -25         52
# 4          -29         49
# ..         ...        ...
# 645         -5         51
# 646        -12         49
# 647         -6         49
# 648         -4         51
# 649         -7         48
#
# [650 rows x 8 columns]
#
# Constituency Winners for model: polls_avg_df
# Year: 2010
#                           Constituency Winner elected_mp_party  \
# 0                     Aberafan Maesteg    LAB              Lab
# 1                            Aldershot    CON              Con
# 2                  Aldridge-Brownhills    CON              Con
# 3             Altrincham and Sale West    CON              Con
# 4                     Alyn and Deeside    LAB              Lab
# ..                                 ...    ...              ...
# 645            Perth and Kinross-shire    SNP              SNP
# 646                         Rutherglen    LAB              Lab
# 647           Stirling and Strathallan    CON              Con
# 648  West Aberdeenshire and Kincardine    SNP              SNP
# 649                West Dunbartonshire    LAB              Lab
#
#     elected_mp_party_name    color                  constituency_name  \
# 0                  Labour  #dd0018                   Aberafan Maesteg
# 1            Conservative  #005af0                          Aldershot
# 2            Conservative  #005af0                Aldridge-Brownhills
# 3            Conservative  #005af0           Altrincham and Sale West
# 4                  Labour  #dd0018                   Alyn and Deeside
# ..                    ...      ...                                ...
# 645                   SNP  #fff293            Perth and Kinross-shire
# 646                Labour  #dd0018                         Rutherglen
# 647          Conservative  #005af0           Stirling and Strathallan
# 648                   SNP  #fff293  West Aberdeenshire and Kincardine
# 649                Labour  #dd0018                West Dunbartonshire
#
#      coord_one  coord_two
# 0          -36         46
# 1          -40         56
# 2          -30         56
# 3          -25         52
# 4          -29         49
# ..         ...        ...
# 645         -5         51
# 646        -12         49
# 647         -6         49
# 648         -4         51
# 649         -7         48
#
# [650 rows x 8 columns]
#
# Year: 2015
#                           Constituency Winner elected_mp_party  \
# 0                     Aberafan Maesteg    LAB              Lab
# 1                            Aldershot    CON              Con
# 2                  Aldridge-Brownhills    CON              Con
# 3             Altrincham and Sale West    CON              Con
# 4                     Alyn and Deeside    LAB              Lab
# ..                                 ...    ...              ...
# 645            Perth and Kinross-shire    SNP              SNP
# 646                         Rutherglen    SNP              SNP
# 647           Stirling and Strathallan    SNP              SNP
# 648  West Aberdeenshire and Kincardine    SNP              SNP
# 649                West Dunbartonshire    SNP              SNP
#
#     elected_mp_party_name    color                  constituency_name  \
# 0                  Labour  #dd0018                   Aberafan Maesteg
# 1            Conservative  #005af0                          Aldershot
# 2            Conservative  #005af0                Aldridge-Brownhills
# 3            Conservative  #005af0           Altrincham and Sale West
# 4                  Labour  #dd0018                   Alyn and Deeside
# ..                    ...      ...                                ...
# 645                   SNP  #fff293            Perth and Kinross-shire
# 646                   SNP  #fff293                         Rutherglen
# 647                   SNP  #fff293           Stirling and Strathallan
# 648                   SNP  #fff293  West Aberdeenshire and Kincardine
# 649                   SNP  #fff293                West Dunbartonshire
#
#      coord_one  coord_two
# 0          -36         46
# 1          -40         56
# 2          -30         56
# 3          -25         52
# 4          -29         49
# ..         ...        ...
# 645         -5         51
# 646        -12         49
# 647         -6         49
# 648         -4         51
# 649         -7         48
#
# [650 rows x 8 columns]
#
# Year: 2017
#                           Constituency Winner elected_mp_party  \
# 0                     Aberafan Maesteg    LAB              Lab
# 1                            Aldershot    CON              Con
# 2                  Aldridge-Brownhills    CON              Con
# 3             Altrincham and Sale West    CON              Con
# 4                     Alyn and Deeside    CON              Con
# ..                                 ...    ...              ...
# 645            Perth and Kinross-shire    SNP              SNP
# 646                         Rutherglen    SNP              SNP
# 647           Stirling and Strathallan    SNP              SNP
# 648  West Aberdeenshire and Kincardine    SNP              SNP
# 649                West Dunbartonshire    SNP              SNP
#
#     elected_mp_party_name    color                  constituency_name  \
# 0                  Labour  #dd0018                   Aberafan Maesteg
# 1            Conservative  #005af0                          Aldershot
# 2            Conservative  #005af0                Aldridge-Brownhills
# 3            Conservative  #005af0           Altrincham and Sale West
# 4            Conservative  #005af0                   Alyn and Deeside
# ..                    ...      ...                                ...
# 645                   SNP  #fff293            Perth and Kinross-shire
# 646                   SNP  #fff293                         Rutherglen
# 647                   SNP  #fff293           Stirling and Strathallan
# 648                   SNP  #fff293  West Aberdeenshire and Kincardine
# 649                   SNP  #fff293                West Dunbartonshire
#
#      coord_one  coord_two
# 0          -36         46
# 1          -40         56
# 2          -30         56
# 3          -25         52
# 4          -29         49
# ..         ...        ...
# 645         -5         51
# 646        -12         49
# 647         -6         49
# 648         -4         51
# 649         -7         48
#
# [650 rows x 8 columns]
#
# Year: 2019
#                           Constituency Winner elected_mp_party  \
# 0                     Aberafan Maesteg    LAB              Lab
# 1                            Aldershot    CON              Con
# 2                  Aldridge-Brownhills    CON              Con
# 3             Altrincham and Sale West    CON              Con
# 4                     Alyn and Deeside    LAB              Lab
# ..                                 ...    ...              ...
# 645            Perth and Kinross-shire    SNP              SNP
# 646                         Rutherglen    SNP              SNP
# 647           Stirling and Strathallan    SNP              SNP
# 648  West Aberdeenshire and Kincardine    SNP              SNP
# 649                West Dunbartonshire    SNP              SNP
#
#     elected_mp_party_name    color                  constituency_name  \
# 0                  Labour  #dd0018                   Aberafan Maesteg
# 1            Conservative  #005af0                          Aldershot
# 2            Conservative  #005af0                Aldridge-Brownhills
# 3            Conservative  #005af0           Altrincham and Sale West
# 4                  Labour  #dd0018                   Alyn and Deeside
# ..                    ...      ...                                ...
# 645                   SNP  #fff293            Perth and Kinross-shire
# 646                   SNP  #fff293                         Rutherglen
# 647                   SNP  #fff293           Stirling and Strathallan
# 648                   SNP  #fff293  West Aberdeenshire and Kincardine
# 649                   SNP  #fff293                West Dunbartonshire
#
#      coord_one  coord_two
# 0          -36         46
# 1          -40         56
# 2          -30         56
# 3          -25         52
# 4          -29         49
# ..         ...        ...
# 645         -5         51
# 646        -12         49
# 647         -6         49
# 648         -4         51
# 649         -7         48
#
# [650 rows x 8 columns]
#
# Year: 2024
#                           Constituency Winner elected_mp_party  \
# 0                     Aberafan Maesteg    LAB              Lab
# 1                            Aldershot    CON              Con
# 2                  Aldridge-Brownhills    CON              Con
# 3             Altrincham and Sale West    LAB              Lab
# 4                     Alyn and Deeside    LAB              Lab
# ..                                 ...    ...              ...
# 645            Perth and Kinross-shire    SNP              SNP
# 646                         Rutherglen    LAB              Lab
# 647           Stirling and Strathallan    SNP              SNP
# 648  West Aberdeenshire and Kincardine    SNP              SNP
# 649                West Dunbartonshire    LAB              Lab
#
#     elected_mp_party_name    color                  constituency_name  \
# 0                  Labour  #dd0018                   Aberafan Maesteg
# 1            Conservative  #005af0                          Aldershot
# 2            Conservative  #005af0                Aldridge-Brownhills
# 3                  Labour  #dd0018           Altrincham and Sale West
# 4                  Labour  #dd0018                   Alyn and Deeside
# ..                    ...      ...                                ...
# 645                   SNP  #fff293            Perth and Kinross-shire
# 646                Labour  #dd0018                         Rutherglen
# 647                   SNP  #fff293           Stirling and Strathallan
# 648                   SNP  #fff293  West Aberdeenshire and Kincardine
# 649                Labour  #dd0018                West Dunbartonshire
#
#      coord_one  coord_two
# 0          -36         46
# 1          -40         56
# 2          -30         56
# 3          -25         52
# 4          -29         49
# ..         ...        ...
# 645         -5         51
# 646        -12         49
# 647         -6         49
# 648         -4         51
# 649         -7         48
#
# [650 rows x 8 columns]
#
# Constituency Winners for model: polls_model_df
# Year: 2010
#                           Constituency Winner elected_mp_party  \
# 0                     Aberafan Maesteg    LAB              Lab
# 1                            Aldershot    CON              Con
# 2                  Aldridge-Brownhills    CON              Con
# 3             Altrincham and Sale West    CON              Con
# 4                     Alyn and Deeside    LAB              Lab
# ..                                 ...    ...              ...
# 645            Perth and Kinross-shire    SNP              SNP
# 646                         Rutherglen    LAB              Lab
# 647           Stirling and Strathallan    CON              Con
# 648  West Aberdeenshire and Kincardine    SNP              SNP
# 649                West Dunbartonshire    LAB              Lab
#
#     elected_mp_party_name    color                  constituency_name  \
# 0                  Labour  #dd0018                   Aberafan Maesteg
# 1            Conservative  #005af0                          Aldershot
# 2            Conservative  #005af0                Aldridge-Brownhills
# 3            Conservative  #005af0           Altrincham and Sale West
# 4                  Labour  #dd0018                   Alyn and Deeside
# ..                    ...      ...                                ...
# 645                   SNP  #fff293            Perth and Kinross-shire
# 646                Labour  #dd0018                         Rutherglen
# 647          Conservative  #005af0           Stirling and Strathallan
# 648                   SNP  #fff293  West Aberdeenshire and Kincardine
# 649                Labour  #dd0018                West Dunbartonshire
#
#      coord_one  coord_two
# 0          -36         46
# 1          -40         56
# 2          -30         56
# 3          -25         52
# 4          -29         49
# ..         ...        ...
# 645         -5         51
# 646        -12         49
# 647         -6         49
# 648         -4         51
# 649         -7         48
#
# [650 rows x 8 columns]
#
# Year: 2015
#                           Constituency Winner elected_mp_party  \
# 0                     Aberafan Maesteg    LAB              Lab
# 1                            Aldershot    CON              Con
# 2                  Aldridge-Brownhills    CON              Con
# 3             Altrincham and Sale West    CON              Con
# 4                     Alyn and Deeside    LAB              Lab
# ..                                 ...    ...              ...
# 645            Perth and Kinross-shire    SNP              SNP
# 646                         Rutherglen    SNP              SNP
# 647           Stirling and Strathallan    SNP              SNP
# 648  West Aberdeenshire and Kincardine    SNP              SNP
# 649                West Dunbartonshire    SNP              SNP
#
#     elected_mp_party_name    color                  constituency_name  \
# 0                  Labour  #dd0018                   Aberafan Maesteg
# 1            Conservative  #005af0                          Aldershot
# 2            Conservative  #005af0                Aldridge-Brownhills
# 3            Conservative  #005af0           Altrincham and Sale West
# 4                  Labour  #dd0018                   Alyn and Deeside
# ..                    ...      ...                                ...
# 645                   SNP  #fff293            Perth and Kinross-shire
# 646                   SNP  #fff293                         Rutherglen
# 647                   SNP  #fff293           Stirling and Strathallan
# 648                   SNP  #fff293  West Aberdeenshire and Kincardine
# 649                   SNP  #fff293                West Dunbartonshire
#
#      coord_one  coord_two
# 0          -36         46
# 1          -40         56
# 2          -30         56
# 3          -25         52
# 4          -29         49
# ..         ...        ...
# 645         -5         51
# 646        -12         49
# 647         -6         49
# 648         -4         51
# 649         -7         48
#
# [650 rows x 8 columns]
#
# Year: 2017
#                           Constituency Winner elected_mp_party  \
# 0                     Aberafan Maesteg    LAB              Lab
# 1                            Aldershot    CON              Con
# 2                  Aldridge-Brownhills    CON              Con
# 3             Altrincham and Sale West    CON              Con
# 4                     Alyn and Deeside    CON              Con
# ..                                 ...    ...              ...
# 645            Perth and Kinross-shire    SNP              SNP
# 646                         Rutherglen    SNP              SNP
# 647           Stirling and Strathallan    SNP              SNP
# 648  West Aberdeenshire and Kincardine    SNP              SNP
# 649                West Dunbartonshire    SNP              SNP
#
#     elected_mp_party_name    color                  constituency_name  \
# 0                  Labour  #dd0018                   Aberafan Maesteg
# 1            Conservative  #005af0                          Aldershot
# 2            Conservative  #005af0                Aldridge-Brownhills
# 3            Conservative  #005af0           Altrincham and Sale West
# 4            Conservative  #005af0                   Alyn and Deeside
# ..                    ...      ...                                ...
# 645                   SNP  #fff293            Perth and Kinross-shire
# 646                   SNP  #fff293                         Rutherglen
# 647                   SNP  #fff293           Stirling and Strathallan
# 648                   SNP  #fff293  West Aberdeenshire and Kincardine
# 649                   SNP  #fff293                West Dunbartonshire
#
#      coord_one  coord_two
# 0          -36         46
# 1          -40         56
# 2          -30         56
# 3          -25         52
# 4          -29         49
# ..         ...        ...
# 645         -5         51
# 646        -12         49
# 647         -6         49
# 648         -4         51
# 649         -7         48
#
# [650 rows x 8 columns]
#
# Year: 2019
#                           Constituency Winner elected_mp_party  \
# 0                     Aberafan Maesteg    LAB              Lab
# 1                            Aldershot    CON              Con
# 2                  Aldridge-Brownhills    CON              Con
# 3             Altrincham and Sale West    CON              Con
# 4                     Alyn and Deeside    LAB              Lab
# ..                                 ...    ...              ...
# 645            Perth and Kinross-shire    SNP              SNP
# 646                         Rutherglen    SNP              SNP
# 647           Stirling and Strathallan    SNP              SNP
# 648  West Aberdeenshire and Kincardine    SNP              SNP
# 649                West Dunbartonshire    SNP              SNP
#
#     elected_mp_party_name    color                  constituency_name  \
# 0                  Labour  #dd0018                   Aberafan Maesteg
# 1            Conservative  #005af0                          Aldershot
# 2            Conservative  #005af0                Aldridge-Brownhills
# 3            Conservative  #005af0           Altrincham and Sale West
# 4                  Labour  #dd0018                   Alyn and Deeside
# ..                    ...      ...                                ...
# 645                   SNP  #fff293            Perth and Kinross-shire
# 646                   SNP  #fff293                         Rutherglen
# 647                   SNP  #fff293           Stirling and Strathallan
# 648                   SNP  #fff293  West Aberdeenshire and Kincardine
# 649                   SNP  #fff293                West Dunbartonshire
#
#      coord_one  coord_two
# 0          -36         46
# 1          -40         56
# 2          -30         56
# 3          -25         52
# 4          -29         49
# ..         ...        ...
# 645         -5         51
# 646        -12         49
# 647         -6         49
# 648         -4         51
# 649         -7         48
#
# [650 rows x 8 columns]
#
# Year: 2024
#                           Constituency Winner elected_mp_party  \
# 0                     Aberafan Maesteg    LAB              Lab
# 1                            Aldershot    CON              Con
# 2                  Aldridge-Brownhills    CON              Con
# 3             Altrincham and Sale West    LAB              Lab
# 4                     Alyn and Deeside    LAB              Lab
# ..                                 ...    ...              ...
# 645            Perth and Kinross-shire    SNP              SNP
# 646                         Rutherglen    LAB              Lab
# 647           Stirling and Strathallan    SNP              SNP
# 648  West Aberdeenshire and Kincardine    SNP              SNP
# 649                West Dunbartonshire    LAB              Lab
#
#     elected_mp_party_name    color                  constituency_name  \
# 0                  Labour  #dd0018                   Aberafan Maesteg
# 1            Conservative  #005af0                          Aldershot
# 2            Conservative  #005af0                Aldridge-Brownhills
# 3                  Labour  #dd0018           Altrincham and Sale West
# 4                  Labour  #dd0018                   Alyn and Deeside
# ..                    ...      ...                                ...
# 645                   SNP  #fff293            Perth and Kinross-shire
# 646                Labour  #dd0018                         Rutherglen
# 647                   SNP  #fff293           Stirling and Strathallan
# 648                   SNP  #fff293  West Aberdeenshire and Kincardine
# 649                Labour  #dd0018                West Dunbartonshire
#
#      coord_one  coord_two
# 0          -36         46
# 1          -40         56
# 2          -30         56
# 3          -25         52
# 4          -29         49
# ..         ...        ...
# 645         -5         51
# 646        -12         49
# 647         -6         49
# 648         -4         51
# 649         -7         48
#
# [650 rows x 8 columns]
#
# Constituency Winners for model: polls_eco_df
# Year: 2010
#                           Constituency Winner elected_mp_party  \
# 0                     Aberafan Maesteg    LAB              Lab
# 1                            Aldershot    CON              Con
# 2                  Aldridge-Brownhills    CON              Con
# 3             Altrincham and Sale West    CON              Con
# 4                     Alyn and Deeside    LAB              Lab
# ..                                 ...    ...              ...
# 645            Perth and Kinross-shire    SNP              SNP
# 646                         Rutherglen    LAB              Lab
# 647           Stirling and Strathallan    CON              Con
# 648  West Aberdeenshire and Kincardine    SNP              SNP
# 649                West Dunbartonshire    LAB              Lab
#
#     elected_mp_party_name    color                  constituency_name  \
# 0                  Labour  #dd0018                   Aberafan Maesteg
# 1            Conservative  #005af0                          Aldershot
# 2            Conservative  #005af0                Aldridge-Brownhills
# 3            Conservative  #005af0           Altrincham and Sale West
# 4                  Labour  #dd0018                   Alyn and Deeside
# ..                    ...      ...                                ...
# 645                   SNP  #fff293            Perth and Kinross-shire
# 646                Labour  #dd0018                         Rutherglen
# 647          Conservative  #005af0           Stirling and Strathallan
# 648                   SNP  #fff293  West Aberdeenshire and Kincardine
# 649                Labour  #dd0018                West Dunbartonshire
#
#      coord_one  coord_two
# 0          -36         46
# 1          -40         56
# 2          -30         56
# 3          -25         52
# 4          -29         49
# ..         ...        ...
# 645         -5         51
# 646        -12         49
# 647         -6         49
# 648         -4         51
# 649         -7         48
#
# [650 rows x 8 columns]
#
# Year: 2015
#                           Constituency Winner elected_mp_party  \
# 0                     Aberafan Maesteg    LAB              Lab
# 1                            Aldershot    CON              Con
# 2                  Aldridge-Brownhills    CON              Con
# 3             Altrincham and Sale West    CON              Con
# 4                     Alyn and Deeside    LAB              Lab
# ..                                 ...    ...              ...
# 645            Perth and Kinross-shire    SNP              SNP
# 646                         Rutherglen    SNP              SNP
# 647           Stirling and Strathallan    SNP              SNP
# 648  West Aberdeenshire and Kincardine    SNP              SNP
# 649                West Dunbartonshire    SNP              SNP
#
#     elected_mp_party_name    color                  constituency_name  \
# 0                  Labour  #dd0018                   Aberafan Maesteg
# 1            Conservative  #005af0                          Aldershot
# 2            Conservative  #005af0                Aldridge-Brownhills
# 3            Conservative  #005af0           Altrincham and Sale West
# 4                  Labour  #dd0018                   Alyn and Deeside
# ..                    ...      ...                                ...
# 645                   SNP  #fff293            Perth and Kinross-shire
# 646                   SNP  #fff293                         Rutherglen
# 647                   SNP  #fff293           Stirling and Strathallan
# 648                   SNP  #fff293  West Aberdeenshire and Kincardine
# 649                   SNP  #fff293                West Dunbartonshire
#
#      coord_one  coord_two
# 0          -36         46
# 1          -40         56
# 2          -30         56
# 3          -25         52
# 4          -29         49
# ..         ...        ...
# 645         -5         51
# 646        -12         49
# 647         -6         49
# 648         -4         51
# 649         -7         48
#
# [650 rows x 8 columns]
#
# Year: 2017
#                           Constituency Winner elected_mp_party  \
# 0                     Aberafan Maesteg    LAB              Lab
# 1                            Aldershot    CON              Con
# 2                  Aldridge-Brownhills    CON              Con
# 3             Altrincham and Sale West    CON              Con
# 4                     Alyn and Deeside    CON              Con
# ..                                 ...    ...              ...
# 645            Perth and Kinross-shire    SNP              SNP
# 646                         Rutherglen    SNP              SNP
# 647           Stirling and Strathallan    SNP              SNP
# 648  West Aberdeenshire and Kincardine    SNP              SNP
# 649                West Dunbartonshire    SNP              SNP
#
#     elected_mp_party_name    color                  constituency_name  \
# 0                  Labour  #dd0018                   Aberafan Maesteg
# 1            Conservative  #005af0                          Aldershot
# 2            Conservative  #005af0                Aldridge-Brownhills
# 3            Conservative  #005af0           Altrincham and Sale West
# 4            Conservative  #005af0                   Alyn and Deeside
# ..                    ...      ...                                ...
# 645                   SNP  #fff293            Perth and Kinross-shire
# 646                   SNP  #fff293                         Rutherglen
# 647                   SNP  #fff293           Stirling and Strathallan
# 648                   SNP  #fff293  West Aberdeenshire and Kincardine
# 649                   SNP  #fff293                West Dunbartonshire
#
#      coord_one  coord_two
# 0          -36         46
# 1          -40         56
# 2          -30         56
# 3          -25         52
# 4          -29         49
# ..         ...        ...
# 645         -5         51
# 646        -12         49
# 647         -6         49
# 648         -4         51
# 649         -7         48
#
# [650 rows x 8 columns]
#
# Year: 2019
#                           Constituency Winner elected_mp_party  \
# 0                     Aberafan Maesteg    LAB              Lab
# 1                            Aldershot    CON              Con
# 2                  Aldridge-Brownhills    CON              Con
# 3             Altrincham and Sale West    CON              Con
# 4                     Alyn and Deeside    LAB              Lab
# ...
# ..                                 ...    ...              ...
# 645            Perth and Kinross-shire    SNP              SNP
# 646                         Rutherglen    SNP              SNP
# 647           Stirling and Strathallan    SNP              SNP
# 648  West Aberdeenshire and Kincardine    SNP              SNP
# 649                West Dunbartonshire    SNP              SNP
#
#     elected_mp_party_name    color                  constituency_name  \
# 0                  Labour  #dd0018                   Aberafan Maesteg
# 1            Conservative  #005af0                          Aldershot
# 2            Conservative  #005af0                Aldridge-Brownhills
# 3            Conservative  #005af0           Altrincham and Sale West
# 4            Conservative  #005af0                   Alyn and Deeside
# ..                    ...      ...                                ...
# 645                   SNP  #fff293            Perth and Kinross-shire
# 646                   SNP  #fff293                         Rutherglen
# 647                   SNP  #fff293           Stirling and Strathallan
# 648                   SNP  #fff293  West Aberdeenshire and Kincardine
# 649                   SNP  #fff293                West Dunbartonshire
#
#      coord_one  coord_two
# 0          -36         46
# 1          -40         56
# 2          -30         56
# 3          -25         52
# 4          -29         49
# ..         ...        ...
# 645         -5         51
# 646        -12         49
# 647         -6         49
# 648         -4         51
# 649         -7         48
#
# [650 rows x 8 columns]
#
# Year: 2019
#                           Constituency Winner elected_mp_party  \
# 0                     Aberafan Maesteg    LAB              Lab
# 1                            Aldershot    CON              Con
# 2                  Aldridge-Brownhills    CON              Con
# 3             Altrincham and Sale West    CON              Con
# 4                     Alyn and Deeside    LAB              Lab
# ..                                 ...    ...              ...
# 645            Perth and Kinross-shire    SNP              SNP
# 646                         Rutherglen    SNP              SNP
# 647           Stirling and Strathallan    SNP              SNP
# 648  West Aberdeenshire and Kincardine    SNP              SNP
# 649                West Dunbartonshire    SNP              SNP
#
#     elected_mp_party_name    color                  constituency_name  \
# 0                  Labour  #dd0018                   Aberafan Maesteg
# 1            Conservative  #005af0                          Aldershot
# 2            Conservative  #005af0                Aldridge-Brownhills
# 3            Conservative  #005af0           Altrincham and Sale West
# 4                  Labour  #dd0018                   Alyn and Deeside
# ..                    ...      ...                                ...
# 645                   SNP  #fff293            Perth and Kinross-shire
# 646                   SNP  #fff293                         Rutherglen
# 647                   SNP  #fff293           Stirling and Strathallan
# 648                   SNP  #fff293  West Aberdeenshire and Kincardine
# 649                   SNP  #fff293                West Dunbartonshire
#
#      coord_one  coord_two
# 0          -36         46
# 1          -40         56
# 2          -30         56
# 3          -25         52
# 4          -29         49
# ..         ...        ...
# 645         -5         51
# 646        -12         49
# 647         -6         49
# 648         -4         51
# 649         -7         48
#
# [650 rows x 8 columns]
#
# Year: 2024
#                           Constituency Winner elected_mp_party  \
# 0                     Aberafan Maesteg    LAB              Lab
# 1                            Aldershot    CON              Con
# 2                  Aldridge-Brownhills    CON              Con
# 3             Altrincham and Sale West    CON              Con
# 4                     Alyn and Deeside    LAB              Lab
# ..                                 ...    ...              ...
# 645            Perth and Kinross-shire    SNP              SNP
# 646                         Rutherglen    LAB              Lab
# 647           Stirling and Strathallan    SNP              SNP
# 648  West Aberdeenshire and Kincardine    SNP              SNP
# 649                West Dunbartonshire    LAB              Lab
#
#     elected_mp_party_name    color                  constituency_name  \
# 0                  Labour  #dd0018                   Aberafan Maesteg
# 1            Conservative  #005af0                          Aldershot
# 2            Conservative  #005af0                Aldridge-Brownhills
# 3            Conservative  #005af0           Altrincham and Sale West
# 4                  Labour  #dd0018                   Alyn and Deeside
# ..                    ...      ...                                ...
# 645                   SNP  #fff293            Perth and Kinross-shire
# 646                Labour  #dd0018                         Rutherglen
# 647                   SNP  #fff293           Stirling and Strathallan
# 648                   SNP  #fff293  West Aberdeenshire and Kincardine
# 649                Labour  #dd0018                West Dunbartonshire
#
#      coord_one  coord_two
# 0          -36         46
# 1          -40         56
# 2          -30         56
# 3          -25         52
# 4          -29         49
# ..         ...        ...
# 645         -5         51
# 646        -12         49
# 647         -6         49
# 648         -4         51
# 649         -7         48
#
# [650 rows x 8 columns]
#
# Constituency Winners for model: polls_eco_alt_df
# Year: 2010
#                           Constituency Winner elected_mp_party  \
# 0                     Aberafan Maesteg    LAB              Lab
# 1                            Aldershot    CON              Con
# 2                  Aldridge-Brownhills    CON              Con
# 3             Altrincham and Sale West    CON              Con
# 4                     Alyn and Deeside    LAB              Lab
# ..                                 ...    ...              ...
# 645            Perth and Kinross-shire    SNP              SNP
# 646                         Rutherglen    LAB              Lab
# 647           Stirling and Strathallan    CON              Con
# 648  West Aberdeenshire and Kincardine    SNP              SNP
# 649                West Dunbartonshire    LAB              Lab
#
#     elected_mp_party_name    color                  constituency_name  \
# 0                  Labour  #dd0018                   Aberafan Maesteg
# 1            Conservative  #005af0                          Aldershot
# 2            Conservative  #005af0                Aldridge-Brownhills
# 3            Conservative  #005af0           Altrincham and Sale West
# 4                  Labour  #dd0018                   Alyn and Deeside
# ..                    ...      ...                                ...
# 645                   SNP  #fff293            Perth and Kinross-shire
# 646                Labour  #dd0018                         Rutherglen
# 647          Conservative  #005af0           Stirling and Strathallan
# 648                   SNP  #fff293  West Aberdeenshire and Kincardine
# 649                Labour  #dd0018                West Dunbartonshire
#
#      coord_one  coord_two
# 0          -36         46
# 1          -40         56
# 2          -30         56
# 3          -25         52
# 4          -29         49
# ..         ...        ...
# 645         -5         51
# 646        -12         49
# 647         -6         49
# 648         -4         51
# 649         -7         48
#
# [650 rows x 8 columns]
#
# Year: 2015
#                           Constituency Winner elected_mp_party  \
# 0                     Aberafan Maesteg    LAB              Lab
# 1                            Aldershot    CON              Con
# 2                  Aldridge-Brownhills    CON              Con
# 3             Altrincham and Sale West    CON              Con
# 4                     Alyn and Deeside    LAB              Lab
# ..                                 ...    ...              ...
# 645            Perth and Kinross-shire    SNP              SNP
# 646                         Rutherglen    SNP              SNP
# 647           Stirling and Strathallan    SNP              SNP
# 648  West Aberdeenshire and Kincardine    SNP              SNP
# 649                West Dunbartonshire    SNP              SNP
#
#     elected_mp_party_name    color                  constituency_name  \
# 0                  Labour  #dd0018                   Aberafan Maesteg
# 1            Conservative  #005af0                          Aldershot
# 2            Conservative  #005af0                Aldridge-Brownhills
# 3            Conservative  #005af0           Altrincham and Sale West
# 4                  Labour  #dd0018                   Alyn and Deeside
# ..                    ...      ...                                ...
# 645                   SNP  #fff293            Perth and Kinross-shire
# 646                   SNP  #fff293                         Rutherglen
# 647                   SNP  #fff293           Stirling and Strathallan
# 648                   SNP  #fff293  West Aberdeenshire and Kincardine
# 649                   SNP  #fff293                West Dunbartonshire
#
#      coord_one  coord_two
# 0          -36         46
# 1          -40         56
# 2          -30         56
# 3          -25         52
# 4          -29         49
# ..         ...        ...
# 645         -5         51
# 646        -12         49
# 647         -6         49
# 648         -4         51
# 649         -7         48
#
# [650 rows x 8 columns]
#
# Year: 2017
#                           Constituency Winner elected_mp_party  \
# 0                     Aberafan Maesteg    LAB              Lab
# 1                            Aldershot    CON              Con
# 2                  Aldridge-Brownhills    CON              Con
# 3             Altrincham and Sale West    CON              Con
# 4                     Alyn and Deeside    CON              Con
# ..                                 ...    ...              ...
# 645            Perth and Kinross-shire    SNP              SNP
# 646                         Rutherglen    SNP              SNP
# 647           Stirling and Strathallan    SNP              SNP
# 648  West Aberdeenshire and Kincardine    SNP              SNP
# 649                West Dunbartonshire    SNP              SNP
#
#     elected_mp_party_name    color                  constituency_name  \
# 0                  Labour  #dd0018                   Aberafan Maesteg
# 1            Conservative  #005af0                          Aldershot
# 2            Conservative  #005af0                Aldridge-Brownhills
# 3            Conservative  #005af0           Altrincham and Sale West
# 4            Conservative  #005af0                   Alyn and Deeside
# ..                    ...      ...                                ...
# 645                   SNP  #fff293            Perth and Kinross-shire
# 646                   SNP  #fff293                         Rutherglen
# 647                   SNP  #fff293           Stirling and Strathallan
# 648                   SNP  #fff293  West Aberdeenshire and Kincardine
# 649                   SNP  #fff293                West Dunbartonshire
#
#      coord_one  coord_two
# 0          -36         46
# 1          -40         56
# 2          -30         56
# 3          -25         52
# 4          -29         49
# ..         ...        ...
# 645         -5         51
# 646        -12         49
# 647         -6         49
# 648         -4         51
# 649         -7         48
#
# [650 rows x 8 columns]
#
# Year: 2019
#                           Constituency Winner elected_mp_party  \
# 0                     Aberafan Maesteg    LAB              Lab
# 1                            Aldershot    CON              Con
# 2                  Aldridge-Brownhills    CON              Con
# 3             Altrincham and Sale West    CON              Con
# 4                     Alyn and Deeside    LAB              Lab
# ..                                 ...    ...              ...
# 645            Perth and Kinross-shire    SNP              SNP
# 646                         Rutherglen    SNP              SNP
# 647           Stirling and Strathallan    SNP              SNP
# 648  West Aberdeenshire and Kincardine    SNP              SNP
# 649                West Dunbartonshire    SNP              SNP
#
#     elected_mp_party_name    color                  constituency_name  \
# 0                  Labour  #dd0018                   Aberafan Maesteg
# 1            Conservative  #005af0                          Aldershot
# 2            Conservative  #005af0                Aldridge-Brownhills
# 3            Conservative  #005af0           Altrincham and Sale West
# 4                  Labour  #dd0018                   Alyn and Deeside
# ..                    ...      ...                                ...
# 645                   SNP  #fff293            Perth and Kinross-shire
# 646                   SNP  #fff293                         Rutherglen
# 647                   SNP  #fff293           Stirling and Strathallan
# 648                   SNP  #fff293  West Aberdeenshire and Kincardine
# 649                   SNP  #fff293                West Dunbartonshire
#
#      coord_one  coord_two
# 0          -36         46
# 1          -40         56
# 2          -30         56
# 3          -25         52
# 4          -29         49
# ..         ...        ...
# 645         -5         51
# 646        -12         49
# 647         -6         49
# 648         -4         51
# 649         -7         48
#
# [650 rows x 8 columns]
#
# Year: 2024
#                           Constituency Winner elected_mp_party  \
# 0                     Aberafan Maesteg    LAB              Lab
# 1                            Aldershot    CON              Con
# 2                  Aldridge-Brownhills    CON              Con
# 3             Altrincham and Sale West    LAB              Lab
# 4                     Alyn and Deeside    LAB              Lab
# ..                                 ...    ...              ...
# 645            Perth and Kinross-shire    SNP              SNP
# 646                         Rutherglen    LAB              Lab
# 647           Stirling and Strathallan    SNP              SNP
# 648  West Aberdeenshire and Kincardine    SNP              SNP
# 649                West Dunbartonshire    LAB              Lab
#
#     elected_mp_party_name    color                  constituency_name  \
# 0                  Labour  #dd0018                   Aberafan Maesteg
# 1            Conservative  #005af0                          Aldershot
# 2            Conservative  #005af0                Aldridge-Brownhills
# 3                  Labour  #dd0018           Altrincham and Sale West
# 4                  Labour  #dd0018                   Alyn and Deeside
# ..                    ...      ...                                ...
# 645                   SNP  #fff293            Perth and Kinross-shire
# 646                Labour  #dd0018                         Rutherglen
# 647                   SNP  #fff293           Stirling and Strathallan
# 648                   SNP  #fff293  West Aberdeenshire and Kincardine
# 649                Labour  #dd0018                West Dunbartonshire
#
#      coord_one  coord_two
# 0          -36         46
# 1          -40         56
# 2          -30         56
# 3          -25         52
# 4          -29         49
# ..         ...        ...
# 645         -5         51
# 646        -12         49
# 647         -6         49
# 648         -4         51
# 649         -7         48
#
# [650 rows x 8 columns]

# %%
import pandas as pd

# Load predictions from csvs
uk_df_dct = {}
uk_df_dct['actuals_df'] = pd.read_excel('../processed_data/election_forecast_tracker.xlsx', sheet_name='actuals', index_col=0)
uk_df_dct['polls_avg_df'] = pd.read_excel('../processed_data/election_forecast_tracker.xlsx', sheet_name='polls_average', index_col=0)
uk_df_dct['polls_model_df'] = pd.read_excel('../processed_data/election_forecast_tracker.xlsx', sheet_name='polls_model', index_col=0)
uk_df_dct['polls_eco_df'] = pd.read_excel('../processed_data/election_forecast_tracker.xlsx', sheet_name='polls_eco', index_col=0)
uk_df_dct['polls_alt_df'] = pd.read_excel('../processed_data/election_forecast_tracker.xlsx', sheet_name='polls_alt', index_col=0)
uk_df_dct['polls_eco_alt_df'] = pd.read_excel('../processed_data/election_forecast_tracker.xlsx', sheet_name='polls_eco_alt', index_col=0)

# Load Scottish forecast data
scotland_df = pd.read_excel('../processed_data/election_forecast_tracker.xlsx', sheet_name='scotland', index_col=0)

# Loading hex constituency mapping
hex_map = pd.read_excel('../processed_data/election_forecast_tracker.xlsx', sheet_name='hex_codes', index_col=0)
constituency_map = pd.read_excel('../processed_data/election_forecast_tracker.xlsx', sheet_name='constituency_coords', index_col=0)

# Define the forecast models
forecast_models = uk_df_dct.copy()

# Import the test bias data
test_bias = pd.read_csv('../processed_data/last_bias.csv', index_col=0)
def calculate_predicted_vote_share(forecast, bias_scores):
    predicted_vote_share = {}
    for party, forecast_share in forecast.items():
        bias_score = bias_scores.get(f"{party}_Bias_Score", 0)
        predicted_vote_share[party] = forecast_share + bias_score
    return predicted_vote_share
def determine_winner(predicted_vote_share):
    return max(predicted_vote_share, key=predicted_vote_share.get)
def determine_winners(forecast, bias_dataframe):
    winners = []
    for index, row in bias_dataframe.iterrows():
        predicted_vote_share = calculate_predicted_vote_share(forecast, row)
        winner = determine_winner(predicted_vote_share)
        winners.append({'Constituency': index, 'Winner': winner})
    return pd.DataFrame(winners)

# Separate Scottish and non-Scottish constituencies in the bias data
scottish_bias = test_bias[test_bias['Scotland'] == True]
uk_test_bias = test_bias[test_bias['Scotland'] == False]

# Container for results
total_constituencies_results = {}
constituency_winners_results = {}

# Loop through each model and each forecast year
for model_name, forecast_df in forecast_models.items():
    model_results = {}
    constituency_winners = {}
    for year in forecast_df.columns:
        forecast = forecast_df[year].dropna().to_dict()
        scotland_forecast = scotland_df[year].dropna().to_dict()

        # Determine winners for UK (excluding Scotland)
        uk_winners_df = determine_winners(forecast, uk_test_bias)
        uk_total_constituencies = uk_winners_df['Winner'].value_counts().reset_index()
        uk_total_constituencies.columns = ['Party', 'Total_Constituencies']

        # Determine winners for Scotland
        scotland_winners_df = determine_winners(scotland_forecast, scottish_bias)
        scotland_total_constituencies = scotland_winners_df['Winner'].value_counts().reset_index()
        scotland_total_constituencies.columns = ['Party', 'Total_Constituencies']

        # Concatenate the results
        total_constituencies = pd.concat([uk_total_constituencies, scotland_total_constituencies]).groupby('Party').sum().reset_index()

        # Add the original vote share to the table
        total_constituencies['Vote_Share'] = total_constituencies['Party'].map(forecast_df[year])

        # Concatenate the constituency winners
        winners_df = pd.concat([uk_winners_df, scotland_winners_df])
        winners_df = pd.merge(winners_df,hex_map,how='left',left_on='Winner',right_on='party_code')
        winners_df = pd.merge(winners_df,constituency_map,how='left',left_on='Constituency',right_on='constituency_name')
        model_results[year] = total_constituencies
        constituency_winners[year] = winners_df
    total_constituencies_results[model_name] = model_results
    constituency_winners_results[model_name] = constituency_winners

# %%
winners_df
# Out:
#                           Constituency Winner elected_mp_party  \
# 0                     Aberafan Maesteg    LAB              Lab
# 1                            Aldershot    CON              Con
# 2                  Aldridge-Brownhills    CON              Con
# 3             Altrincham and Sale West    LAB              Lab
# 4                     Alyn and Deeside    LAB              Lab
# ..                                 ...    ...              ...
# 645            Perth and Kinross-shire    SNP              SNP
# 646                         Rutherglen    LAB              Lab
# 647           Stirling and Strathallan    CON              Con
# 648  West Aberdeenshire and Kincardine    LAB              Lab
# 649                West Dunbartonshire    LAB              Lab
#
#     elected_mp_party_name    color constituency_id  coord_one  coord_two
# 0                  Labour  #dd0018             NaN        NaN        NaN
# 1            Conservative  #005af0       E14000530       -3.0      -11.0
# 2            Conservative  #005af0       E14000531       -3.0       -1.0
# 3                  Labour  #dd0018       E14000532       -7.0        3.0
# 4                  Labour  #dd0018       W07000043      -10.0        1.0
# ..                    ...      ...             ...        ...        ...
# 645                   SNP  #fff293             NaN        NaN        NaN
# 646                Labour  #dd0018             NaN        NaN        NaN
# 647          Conservative  #005af0             NaN        NaN        NaN
# 648                Labour  #dd0018       S14000058       -4.0       24.0
# 649                Labour  #dd0018       S14000059       -9.0       22.0
#
# [650 rows x 8 columns]

# %%
# Create an Excel writer
with pd.ExcelWriter('election_results.xlsx') as writer:

    # Write total constituencies results to Excel
    for model_name, results in total_constituencies_results.items():
        for year, df in results.items():
            sheet_name = f"{model_name}_{year}_total"
            df.to_excel(writer, sheet_name=sheet_name, index=False)

    # Write constituency winners results to Excel
    for model_name, results in constituency_winners_results.items():
        for year, df in results.items():
            sheet_name = f"{model_name}_{year}_winners"
            df.to_excel(writer, sheet_name=sheet_name, index=False)

# Display the results for verification
for model_name, results in total_constituencies_results.items():
    print(f"Results for model: {model_name}")
    for year, df in results.items():
        print(f"Year: {year}")
        print(df)
        print()

for model_name, results in constituency_winners_results.items():
    print(f"Constituency Winners for model: {model_name}")
    for year, df in results.items():
        print(f"Year: {year}")
        print(df)
        print()
# Out:
# Results for model: actuals_df
# Year: 2010
#   Party  Total_Constituencies  Vote_Share
# 0   CON                   321        36.2
# 1   GRE                     1         0.7
# 2   LAB                   264        29.2
# 3   LIB                    40        23.5
# 4   OTH                    19        10.8
# 5   PLC                     3         0.6
# 6   SNP                     2         3.4
#
# Year: 2015
#   Party  Total_Constituencies  Vote_Share
# 0   CON                   337        36.9
# 1   GRE                     1         3.8
# 2   LAB                   227        30.4
# 3   LIB                     8         7.9
# 4   OTH                    19         3.1
# 5   PLC                     4         0.6
# 6   SNP                    54         4.7
#
# Year: 2017
#   Party  Total_Constituencies  Vote_Share
# 0   CON                   326        42.4
# 1   GRE                     1         1.6
# 2   LAB                   246        40.0
# 3   LIB                     7         7.4
# 4   OTH                    19         3.3
# 5   PLC                     4         0.5
# 6   SNP                    47         3.0
#
# Year: 2019
#   Party  Total_Constituencies  Vote_Share
# 0   CON                   363        43.8
# 1   GRE                    50         3.5
# 2   LAB                   203        32.7
# 3   LIB                    10        11.6
# 4   OTH                    19         3.1
# 5   PLC                     4         0.5
# 6   SNP                     1         3.8
#
# Year: 2024
#        Party  Total_Constituencies  Vote_Share
# 0  BRX + UKI                    16        12.5
# 1        CON                   148        23.0
# 2        GRE                     1         5.8
# 3        LAB                   450        44.1
# 4        LIB                    29         9.5
# 5        SNP                     6         NaN
#
# Results for model: polls_avg_df
# Year: 2010
#   Party  Total_Constituencies  Vote_Share
# 0   CON                   331        37.6
# 1   GRE                     1         0.0
# 2   LAB                   264        30.5
# 3   LIB                    30        19.5
# 4   OTH                    19        12.3
# 5   PLC                     3         0.0
# 6   SNP                     2         0.0
#
# Year: 2015
#   Party  Total_Constituencies  Vote_Share
# 0   CON                   293        33.5
# 1   GRE                     1         5.3
# 2   LAB                   266        34.0
# 3   LIB                    13         8.0
# 4   OTH                    19         5.5
# 5   PLC                     4         0.0
# 6   SNP                    54         0.0
#
# Year: 2017
#   Party  Total_Constituencies  Vote_Share
# 0   CON                   411        46.7
# 1   GRE                     1         2.9
# 2   LAB                   160        28.5
# 3   LIB                     7         9.7
# 4   OTH                    19         1.5
# 5   PLC                     4         0.6
# 6   SNP                    48         4.2
#
# Year: 2019
#   Party  Total_Constituencies  Vote_Share
# 0   CON                   358        39.6
# 1   GRE                    50         3.9
# 2   LAB                   196        27.8
# 3   LIB                    21        15.8
# 4   OTH                    19         1.1
# 5   PLC                     4         0.5
# 6   SNP                     2         3.7
#
# Year: 2024
#   Party  Total_Constituencies  Vote_Share
# 0   CON                   147        23.2
# 1   GRE                     1         5.7
# 2   LAB                   446        44.6
# 3   LIB                    27         9.4
# 4   OTH                    19         1.9
# 5   PLC                     4         0.7
# 6   SNP                     6         2.7
#
# Results for model: polls_model_df
# Year: 2010
#   Party  Total_Constituencies  Vote_Share
# 0   CON                   324        37.0
# 1   GRE                     1         0.9
# 2   LAB                   270        31.0
# 3   LIB                    31        19.7
# 4   OTH                    19        11.5
# 5   PLC                     3         0.6
# 6   SNP                     2         3.7
#
# Year: 2015
#   Party  Total_Constituencies  Vote_Share
# 0   CON                   293        33.5
# 1   GRE                     1         5.3
# 2   LAB                   266        34.0
# 3   LIB                    13         8.0
# 4   OTH                    19         5.5
# 5   PLC                     4         0.5
# 6   SNP                    54         4.0
#
# Year: 2017
#   Party  Total_Constituencies  Vote_Share
# 0   CON                   411        46.7
# 1   GRE                     1         1.7
# 2   LAB                   160        28.4
# 3   LIB                     7         9.7
# 4   OTH                    19         1.5
# 5   PLC                     4         0.6
# 6   SNP                    48         4.2
#
# Year: 2019
#   Party  Total_Constituencies  Vote_Share
# 0   CON                   350        40.4
# 1   GRE                    50         2.5
# 2   LAB                   209        31.3
# 3   LIB                    18        15.1
# 4   OTH                    19         1.3
# 5   PLC                     3         0.5
# 6   SNP                     1         3.5
#
# Year: 2024
#   Party  Total_Constituencies  Vote_Share
# 0   CON                   183       24.40
# 1   GRE                     1        5.30
# 2   LAB                   411       41.10
# 3   LIB                    26        9.10
# 4   OTH                    19        2.30
# 5   PLC                     4        0.66
# 6   SNP                     6        2.90
#
# Results for model: polls_eco_df
# Year: 2010
#   Party  Total_Constituencies  Vote_Share
# 0   CON                   324        37.1
# 1   GRE                     1         0.9
# 2   LAB                   270        31.0
# 3   LIB                    31        19.7
# 4   OTH                    19        11.5
# 5   PLC                     3         0.0
# 6   SNP                     2         1.9
#
# Year: 2015
#   Party  Total_Constituencies  Vote_Share
# 0   CON                   291        33.4
# 1   GRE                     1         5.3
# 2   LAB                   267        34.0
# 3   LIB                    14         9.0
# 4   OTH                    19         5.5
# 5   PLC                     4         0.5
# 6   SNP                    54         4.0
#
# Year: 2017
#   Party  Total_Constituencies  Vote_Share
# 0   CON                   411        46.7
# 1   GRE                     1         2.9
# 2   LAB                   160        28.5
# 3   LIB                     7         9.7
# 4   OTH                    19         1.2
# 5   PLC                     4         0.5
# 6   SNP                    48         3.3
#
# Year: 2019
#   Party  Total_Constituencies  Vote_Share
# 0   CON                   347        40.7
# 1   GRE                    50         3.6
# 2   LAB                   212        31.9
# 3   LIB                    18        15.2
# 4   OTH                    19         1.4
# 5   PLC                     3         0.5
# 6   SNP                     1         3.5
#
# Year: 2024
#   Party  Total_Constituencies  Vote_Share
# 0   CON                   230       31.00
# 1   GRE                     1        4.80
# 2   LAB                   373       44.00
# 3   LIB                    17        9.10
# 4   OTH                    19        2.50
# 5   PLC                     4        0.46
# 6   SNP                     6        2.80
#
# Results for model: polls_alt_df
# Year: 2010
#   Party  Total_Constituencies  Vote_Share
# 0   CON                   296        34.4
# 1   GRE                     1         0.9
# 2   LAB                   284        31.7
# 3   LIB                    45        22.6
# 4   OTH                    19         5.4
# 5   PLC                     3         0.6
# 6   SNP                     2         3.8
#
# Year: 2015
#   Party  Total_Constituencies  Vote_Share
# 0   CON                   294        33.6
# 1   GRE                     1         5.3
# 2   LAB                   265        33.7
# 3   LIB                    13         8.0
# 4   OTH                    19         5.4
# 5   PLC                     4         0.6
# 6   SNP                    54         4.2
#
# Year: 2017
#   Party  Total_Constituencies  Vote_Share
# 0   CON                   411        46.7
# 1   GRE                     1         2.9
# 2   LAB                   160        28.5
# 3   LIB                     7         9.7
# 4   OTH                    19         1.1
# 5   PLC                     4         0.6
# 6   SNP                    48         3.3
#
# Year: 2019
#   Party  Total_Constituencies  Vote_Share
# 0   CON                   338        40.2
# 1   GRE                    50         3.7
# 2   LAB                   221        32.7
# 3   LIB                    18        14.3
# 4   OTH                    19         1.1
# 5   PLC                     3         0.3
# 6   SNP                     1         3.5
#
# Year: 2024
#   Party  Total_Constituencies  Vote_Share
# 0   CON                   245       29.70
# 1   GRE                     1        5.30
# 2   LAB                   356       39.40
# 3   LIB                    19        9.70
# 4   OTH                    19        2.50
# 5   PLC                     4        0.45
# 6   SNP                     6        2.90
#
# Results for model: polls_eco_alt_df
# Year: 2010
#   Party  Total_Constituencies  Vote_Share
# 0   CON                   301        35.2
# 1   GRE                     1         0.4
# 2   LAB                   286        32.7
# 3   LIB                    38        20.7
# 4   OTH                    19         8.9
# 5   PLC                     3         0.3
# 6   SNP                     2         1.9
#
# Year: 2015
#   Party  Total_Constituencies  Vote_Share
# 0   CON                   289        33.3
# 1   GRE                     1         5.2
# 2   LAB                   270        34.2
# 3   LIB                    13         7.9
# 4   OTH                    19         5.4
# 5   PLC                     4         0.5
# 6   SNP                    54         1.8
#
# Year: 2017
#   Party  Total_Constituencies  Vote_Share
# 0   CON                   411        46.7
# 1   GRE                     1         1.9
# 2   LAB                   160        28.6
# 3   LIB                     7         9.7
# 4   OTH                    19         1.2
# 5   PLC                     4         0.7
# 6   SNP                    48         3.3
#
# Year: 2019
#   Party  Total_Constituencies  Vote_Share
# 0   CON                   333        40.0
# 1   GRE                    50         3.9
# 2   LAB                   225        33.5
# 3   LIB                    19        15.8
# 4   OTH                    19         1.0
# 5   PLC                     3         0.5
# 6   SNP                     1         3.8
#
# Year: 2024
#   Party  Total_Constituencies  Vote_Share
# 0   CON                   219       28.10
# 1   GRE                     1        5.20
# 2   LAB                   381       42.00
# 3   LIB                    20        9.10
# 4   OTH                    19        2.40
# 5   PLC                     4        0.46
# 6   SNP                     6        2.90
#
# Constituency Winners for model: actuals_df
# Year: 2010
#                           Constituency Winner elected_mp_party  \
# 0                     Aberafan Maesteg    LAB              Lab
# 1                            Aldershot    CON              Con
# 2                  Aldridge-Brownhills    CON              Con
# 3             Altrincham and Sale West    CON              Con
# 4                     Alyn and Deeside    LAB              Lab
# ..                                 ...    ...              ...
# 645            Perth and Kinross-shire    SNP              SNP
# 646                         Rutherglen    LAB              Lab
# 647           Stirling and Strathallan    CON              Con
# 648  West Aberdeenshire and Kincardine    LAB              Lab
# 649                West Dunbartonshire    LAB              Lab
#
#     elected_mp_party_name    color constituency_id  coord_one  coord_two
# 0                  Labour  #dd0018             NaN        NaN        NaN
# 1            Conservative  #005af0       E14000530       -3.0      -11.0
# 2            Conservative  #005af0       E14000531       -3.0       -1.0
# 3            Conservative  #005af0       E14000532       -7.0        3.0
# 4                  Labour  #dd0018       W07000043      -10.0        1.0
# ..                    ...      ...             ...        ...        ...
# 645                   SNP  #fff293             NaN        NaN        NaN
# 646                Labour  #dd0018             NaN        NaN        NaN
# 647          Conservative  #005af0             NaN        NaN        NaN
# 648                Labour  #dd0018       S14000058       -4.0       24.0
# 649                Labour  #dd0018       S14000059       -9.0       22.0
#
# [650 rows x 8 columns]
#
# Year: 2015
#                           Constituency Winner elected_mp_party  \
# 0                     Aberafan Maesteg    LAB              Lab
# 1                            Aldershot    CON              Con
# 2                  Aldridge-Brownhills    CON              Con
# 3             Altrincham and Sale West    CON              Con
# 4                     Alyn and Deeside    LAB              Lab
# ..                                 ...    ...              ...
# 645            Perth and Kinross-shire    SNP              SNP
# 646                         Rutherglen    SNP              SNP
# 647           Stirling and Strathallan    SNP              SNP
# 648  West Aberdeenshire and Kincardine    SNP              SNP
# 649                West Dunbartonshire    SNP              SNP
#
#     elected_mp_party_name    color constituency_id  coord_one  coord_two
# 0                  Labour  #dd0018             NaN        NaN        NaN
# 1            Conservative  #005af0       E14000530       -3.0      -11.0
# 2            Conservative  #005af0       E14000531       -3.0       -1.0
# 3            Conservative  #005af0       E14000532       -7.0        3.0
# 4                  Labour  #dd0018       W07000043      -10.0        1.0
# ..                    ...      ...             ...        ...        ...
# 645                   SNP  #fff293             NaN        NaN        NaN
# 646                   SNP  #fff293             NaN        NaN        NaN
# 647                   SNP  #fff293             NaN        NaN        NaN
# 648                   SNP  #fff293       S14000058       -4.0       24.0
# 649                   SNP  #fff293       S14000059       -9.0       22.0
#
# [650 rows x 8 columns]
#
# Year: 2017
#                           Constituency Winner elected_mp_party  \
# 0                     Aberafan Maesteg    LAB              Lab
# 1                            Aldershot    CON              Con
# 2                  Aldridge-Brownhills    CON              Con
# 3             Altrincham and Sale West    CON              Con
# 4                     Alyn and Deeside    LAB              Lab
# ..                                 ...    ...              ...
# 645            Perth and Kinross-shire    SNP              SNP
# 646                         Rutherglen    SNP              SNP
# 647           Stirling and Strathallan    CON              Con
# 648  West Aberdeenshire and Kincardine    SNP              SNP
# 649                West Dunbartonshire    SNP              SNP
#
#     elected_mp_party_name    color constituency_id  coord_one  coord_two
# 0                  Labour  #dd0018             NaN        NaN        NaN
# 1            Conservative  #005af0       E14000530       -3.0      -11.0
# 2            Conservative  #005af0       E14000531       -3.0       -1.0
# 3            Conservative  #005af0       E14000532       -7.0        3.0
# 4                  Labour  #dd0018       W07000043      -10.0        1.0
# ..                    ...      ...             ...        ...        ...
# 645                   SNP  #fff293             NaN        NaN        NaN
# 646                   SNP  #fff293             NaN        NaN        NaN
# 647          Conservative  #005af0             NaN        NaN        NaN
# 648                   SNP  #fff293       S14000058       -4.0       24.0
# 649                   SNP  #fff293       S14000059       -9.0       22.0
#
# [650 rows x 8 columns]
#
# Year: 2019
#                           Constituency Winner elected_mp_party  \
# 0                     Aberafan Maesteg    LAB              Lab
# 1                            Aldershot    CON              Con
# 2                  Aldridge-Brownhills    CON              Con
# 3             Altrincham and Sale West    CON              Con
# 4                     Alyn and Deeside    LAB              Lab
# ..                                 ...    ...              ...
# 645            Perth and Kinross-shire    GRE            Green
# 646                         Rutherglen    GRE            Green
# 647           Stirling and Strathallan    CON              Con
# 648  West Aberdeenshire and Kincardine    GRE            Green
# 649                West Dunbartonshire    GRE            Green
#
#     elected_mp_party_name    color constituency_id  coord_one  coord_two
# 0                  Labour  #dd0018             NaN        NaN        NaN
# 1            Conservative  #005af0       E14000530       -3.0      -11.0
# 2            Conservative  #005af0       E14000531       -3.0       -1.0
# 3            Conservative  #005af0       E14000532       -7.0        3.0
# 4                  Labour  #dd0018       W07000043      -10.0        1.0
# ..                    ...      ...             ...        ...        ...
# 645                 Green  #00bc3e             NaN        NaN        NaN
# 646                 Green  #00bc3e             NaN        NaN        NaN
# 647          Conservative  #005af0             NaN        NaN        NaN
# 648                 Green  #00bc3e       S14000058       -4.0       24.0
# 649                 Green  #00bc3e       S14000059       -9.0       22.0
#
# [650 rows x 8 columns]
#
# Year: 2024
#                           Constituency Winner elected_mp_party  \
# 0                     Aberafan Maesteg    LAB              Lab
# 1                            Aldershot    CON              Con
# 2                  Aldridge-Brownhills    CON              Con
# 3             Altrincham and Sale West    LAB              Lab
# 4                     Alyn and Deeside    LAB              Lab
# ..                                 ...    ...              ...
# 645            Perth and Kinross-shire    SNP              SNP
# 646                         Rutherglen    LAB              Lab
# 647           Stirling and Strathallan    CON              Con
# 648  West Aberdeenshire and Kincardine    LAB              Lab
# 649                West Dunbartonshire    LAB              Lab
#
#     elected_mp_party_name    color constituency_id  coord_one  coord_two
# 0                  Labour  #dd0018             NaN        NaN        NaN
# 1            Conservative  #005af0       E14000530       -3.0      -11.0
# 2            Conservative  #005af0       E14000531       -3.0       -1.0
# 3                  Labour  #dd0018       E14000532       -7.0        3.0
# 4                  Labour  #dd0018       W07000043      -10.0        1.0
# ..                    ...      ...             ...        ...        ...
# 645                   SNP  #fff293             NaN        NaN        NaN
# 646                Labour  #dd0018             NaN        NaN        NaN
# 647          Conservative  #005af0             NaN        NaN        NaN
# 648                Labour  #dd0018       S14000058       -4.0       24.0
# 649                Labour  #dd0018       S14000059       -9.0       22.0
#
# [650 rows x 8 columns]
#
# Constituency Winners for model: polls_avg_df
# Year: 2010
#                           Constituency Winner elected_mp_party  \
# 0                     Aberafan Maesteg    LAB              Lab
# 1                            Aldershot    CON              Con
# 2                  Aldridge-Brownhills    CON              Con
# 3             Altrincham and Sale West    CON              Con
# 4                     Alyn and Deeside    LAB              Lab
# ..                                 ...    ...              ...
# 645            Perth and Kinross-shire    SNP              SNP
# 646                         Rutherglen    LAB              Lab
# 647           Stirling and Strathallan    CON              Con
# 648  West Aberdeenshire and Kincardine    LAB              Lab
# 649                West Dunbartonshire    LAB              Lab
#
#     elected_mp_party_name    color constituency_id  coord_one  coord_two
# 0                  Labour  #dd0018             NaN        NaN        NaN
# 1            Conservative  #005af0       E14000530       -3.0      -11.0
# 2            Conservative  #005af0       E14000531       -3.0       -1.0
# 3            Conservative  #005af0       E14000532       -7.0        3.0
# 4                  Labour  #dd0018       W07000043      -10.0        1.0
# ..                    ...      ...             ...        ...        ...
# 645                   SNP  #fff293             NaN        NaN        NaN
# 646                Labour  #dd0018             NaN        NaN        NaN
# 647          Conservative  #005af0             NaN        NaN        NaN
# 648                Labour  #dd0018       S14000058       -4.0       24.0
# 649                Labour  #dd0018       S14000059       -9.0       22.0
#
# [650 rows x 8 columns]
#
# Year: 2015
#                           Constituency Winner elected_mp_party  \
# 0                     Aberafan Maesteg    LAB              Lab
# 1                            Aldershot    CON              Con
# 2                  Aldridge-Brownhills    CON              Con
# 3             Altrincham and Sale West    CON              Con
# 4                     Alyn and Deeside    LAB              Lab
# ..                                 ...    ...              ...
# 645            Perth and Kinross-shire    SNP              SNP
# 646                         Rutherglen    SNP              SNP
# 647           Stirling and Strathallan    SNP              SNP
# 648  West Aberdeenshire and Kincardine    SNP              SNP
# 649                West Dunbartonshire    SNP              SNP
#
#     elected_mp_party_name    color constituency_id  coord_one  coord_two
# 0                  Labour  #dd0018             NaN        NaN        NaN
# 1            Conservative  #005af0       E14000530       -3.0      -11.0
# 2            Conservative  #005af0       E14000531       -3.0       -1.0
# 3            Conservative  #005af0       E14000532       -7.0        3.0
# 4                  Labour  #dd0018       W07000043      -10.0        1.0
# ..                    ...      ...             ...        ...        ...
# 645                   SNP  #fff293             NaN        NaN        NaN
# 646                   SNP  #fff293             NaN        NaN        NaN
# 647                   SNP  #fff293             NaN        NaN        NaN
# 648                   SNP  #fff293       S14000058       -4.0       24.0
# 649                   SNP  #fff293       S14000059       -9.0       22.0
#
# [650 rows x 8 columns]
#
# Year: 2017
#                           Constituency Winner elected_mp_party  \
# 0                     Aberafan Maesteg    LAB              Lab
# 1                            Aldershot    CON              Con
# 2                  Aldridge-Brownhills    CON              Con
# 3             Altrincham and Sale West    CON              Con
# 4                     Alyn and Deeside    CON              Con
# ..                                 ...    ...              ...
# 645            Perth and Kinross-shire    SNP              SNP
# 646                         Rutherglen    SNP              SNP
# 647           Stirling and Strathallan    CON              Con
# 648  West Aberdeenshire and Kincardine    SNP              SNP
# 649                West Dunbartonshire    SNP              SNP
#
#     elected_mp_party_name    color constituency_id  coord_one  coord_two
# 0                  Labour  #dd0018             NaN        NaN        NaN
# 1            Conservative  #005af0       E14000530       -3.0      -11.0
# 2            Conservative  #005af0       E14000531       -3.0       -1.0
# 3            Conservative  #005af0       E14000532       -7.0        3.0
# 4            Conservative  #005af0       W07000043      -10.0        1.0
# ..                    ...      ...             ...        ...        ...
# 645                   SNP  #fff293             NaN        NaN        NaN
# 646                   SNP  #fff293             NaN        NaN        NaN
# 647          Conservative  #005af0             NaN        NaN        NaN
# 648                   SNP  #fff293       S14000058       -4.0       24.0
# 649                   SNP  #fff293       S14000059       -9.0       22.0
#
# [650 rows x 8 columns]
#
# Year: 2019
#                           Constituency Winner elected_mp_party  \
# 0                     Aberafan Maesteg    LAB              Lab
# 1                            Aldershot    CON              Con
# 2                  Aldridge-Brownhills    CON              Con
# 3             Altrincham and Sale West    CON              Con
# 4                     Alyn and Deeside    LAB              Lab
# ..                                 ...    ...              ...
# 645            Perth and Kinross-shire    GRE            Green
# 646                         Rutherglen    GRE            Green
# 647           Stirling and Strathallan    CON              Con
# 648  West Aberdeenshire and Kincardine    GRE            Green
# 649                West Dunbartonshire    GRE            Green
#
#     elected_mp_party_name    color constituency_id  coord_one  coord_two
# 0                  Labour  #dd0018             NaN        NaN        NaN
# 1            Conservative  #005af0       E14000530       -3.0      -11.0
# 2            Conservative  #005af0       E14000531       -3.0       -1.0
# 3            Conservative  #005af0       E14000532       -7.0        3.0
# 4                  Labour  #dd0018       W07000043      -10.0        1.0
# ..                    ...      ...             ...        ...        ...
# 645                 Green  #00bc3e             NaN        NaN        NaN
# 646                 Green  #00bc3e             NaN        NaN        NaN
# 647          Conservative  #005af0             NaN        NaN        NaN
# 648                 Green  #00bc3e       S14000058       -4.0       24.0
# 649                 Green  #00bc3e       S14000059       -9.0       22.0
#
# [650 rows x 8 columns]
#
# Year: 2024
#                           Constituency Winner elected_mp_party  \
# 0                     Aberafan Maesteg    LAB              Lab
# 1                            Aldershot    CON              Con
# 2                  Aldridge-Brownhills    CON              Con
# 3             Altrincham and Sale West    LAB              Lab
# 4                     Alyn and Deeside    LAB              Lab
# ..                                 ...    ...              ...
# 645            Perth and Kinross-shire    SNP              SNP
# 646                         Rutherglen    LAB              Lab
# 647           Stirling and Strathallan    CON              Con
# 648  West Aberdeenshire and Kincardine    LAB              Lab
# 649                West Dunbartonshire    LAB              Lab
#
#     elected_mp_party_name    color constituency_id  coord_one  coord_two
# 0                  Labour  #dd0018             NaN        NaN        NaN
# 1            Conservative  #005af0       E14000530       -3.0      -11.0
# 2            Conservative  #005af0       E14000531       -3.0       -1.0
# 3                  Labour  #dd0018       E14000532       -7.0        3.0
# 4                  Labour  #dd0018       W07000043      -10.0        1.0
# ..                    ...      ...             ...        ...        ...
# 645                   SNP  #fff293             NaN        NaN        NaN
# 646                Labour  #dd0018             NaN        NaN        NaN
# 647          Conservative  #005af0             NaN        NaN        NaN
# 648                Labour  #dd0018       S14000058       -4.0       24.0
# 649                Labour  #dd0018       S14000059       -9.0       22.0
#
# [650 rows x 8 columns]
#
# Constituency Winners for model: polls_model_df
# Year: 2010
#                           Constituency Winner elected_mp_party  \
# 0                     Aberafan Maesteg    LAB              Lab
# 1                            Aldershot    CON              Con
# 2                  Aldridge-Brownhills    CON              Con
# 3             Altrincham and Sale West    CON              Con
# 4                     Alyn and Deeside    LAB              Lab
# ..                                 ...    ...              ...
# 645            Perth and Kinross-shire    SNP              SNP
# 646                         Rutherglen    LAB              Lab
# 647           Stirling and Strathallan    CON              Con
# 648  West Aberdeenshire and Kincardine    LAB              Lab
# 649                West Dunbartonshire    LAB              Lab
#
#     elected_mp_party_name    color constituency_id  coord_one  coord_two
# 0                  Labour  #dd0018             NaN        NaN        NaN
# 1            Conservative  #005af0       E14000530       -3.0      -11.0
# 2            Conservative  #005af0       E14000531       -3.0       -1.0
# 3            Conservative  #005af0       E14000532       -7.0        3.0
# 4                  Labour  #dd0018       W07000043      -10.0        1.0
# ..                    ...      ...             ...        ...        ...
# 645                   SNP  #fff293             NaN        NaN        NaN
# 646                Labour  #dd0018             NaN        NaN        NaN
# 647          Conservative  #005af0             NaN        NaN        NaN
# 648                Labour  #dd0018       S14000058       -4.0       24.0
# 649                Labour  #dd0018       S14000059       -9.0       22.0
#
# [650 rows x 8 columns]
#
# Year: 2015
#                           Constituency Winner elected_mp_party  \
# 0                     Aberafan Maesteg    LAB              Lab
# 1                            Aldershot    CON              Con
# 2                  Aldridge-Brownhills    CON              Con
# 3             Altrincham and Sale West    CON              Con
# 4                     Alyn and Deeside    LAB              Lab
# ..                                 ...    ...              ...
# 645            Perth and Kinross-shire    SNP              SNP
# 646                         Rutherglen    SNP              SNP
# 647           Stirling and Strathallan    SNP              SNP
# 648  West Aberdeenshire and Kincardine    SNP              SNP
# 649                West Dunbartonshire    SNP              SNP
#
#     elected_mp_party_name    color constituency_id  coord_one  coord_two
# 0                  Labour  #dd0018             NaN        NaN        NaN
# 1            Conservative  #005af0       E14000530       -3.0      -11.0
# 2            Conservative  #005af0       E14000531       -3.0       -1.0
# 3            Conservative  #005af0       E14000532       -7.0        3.0
# 4                  Labour  #dd0018       W07000043      -10.0        1.0
# ..                    ...      ...             ...        ...        ...
# 645                   SNP  #fff293             NaN        NaN        NaN
# 646                   SNP  #fff293             NaN        NaN        NaN
# 647                   SNP  #fff293             NaN        NaN        NaN
# 648                   SNP  #fff293       S14000058       -4.0       24.0
# 649                   SNP  #fff293       S14000059       -9.0       22.0
#
# [650 rows x 8 columns]
#
# Year: 2017
#                           Constituency Winner elected_mp_party  \
# 0                     Aberafan Maesteg    LAB              Lab
# 1                            Aldershot    CON              Con
# 2                  Aldridge-Brownhills    CON              Con
# 3             Altrincham and Sale West    CON              Con
# 4                     Alyn and Deeside    CON              Con
# ..                                 ...    ...              ...
# 645            Perth and Kinross-shire    SNP              SNP
# 646                         Rutherglen    SNP              SNP
# 647           Stirling and Strathallan    CON              Con
# 648  West Aberdeenshire and Kincardine    SNP              SNP
# 649                West Dunbartonshire    SNP              SNP
#
#     elected_mp_party_name    color constituency_id  coord_one  coord_two
# 0                  Labour  #dd0018             NaN        NaN        NaN
# 1            Conservative  #005af0       E14000530       -3.0      -11.0
# 2            Conservative  #005af0       E14000531       -3.0       -1.0
# 3            Conservative  #005af0       E14000532       -7.0        3.0
# 4            Conservative  #005af0       W07000043      -10.0        1.0
# ..                    ...      ...             ...        ...        ...
# 645                   SNP  #fff293             NaN        NaN        NaN
# 646                   SNP  #fff293             NaN        NaN        NaN
# 647          Conservative  #005af0             NaN        NaN        NaN
# 648                   SNP  #fff293       S14000058       -4.0       24.0
# 649                   SNP  #fff293       S14000059       -9.0       22.0
#
# [650 rows x 8 columns]
#
# Year: 2019
#                           Constituency Winner elected_mp_party  \
# 0                     Aberafan Maesteg    LAB              Lab
# 1                            Aldershot    CON              Con
# 2                  Aldridge-Brownhills    CON              Con
# 3             Altrincham and Sale West    CON              Con
# 4                     Alyn and Deeside    LAB              Lab
# ..                                 ...    ...              ...
# 645            Perth and Kinross-shire    GRE            Green
# 646                         Rutherglen    GRE            Green
# 647           Stirling and Strathallan    CON              Con
# 648  West Aberdeenshire and Kincardine    GRE            Green
# 649                West Dunbartonshire    GRE            Green
#
#     elected_mp_party_name    color constituency_id  coord_one  coord_two
# 0                  Labour  #dd0018             NaN        NaN        NaN
# 1            Conservative  #005af0       E14000530       -3.0      -11.0
# 2            Conservative  #005af0       E14000531       -3.0       -1.0
# 3            Conservative  #005af0       E14000532       -7.0        3.0
# 4                  Labour  #dd0018       W07000043      -10.0        1.0
# ..                    ...      ...             ...        ...        ...
# 645                 Green  #00bc3e             NaN        NaN        NaN
# 646                 Green  #00bc3e             NaN        NaN        NaN
# 647          Conservative  #005af0             NaN        NaN        NaN
# 648                 Green  #00bc3e       S14000058       -4.0       24.0
# 649                 Green  #00bc3e       S14000059       -9.0       22.0
#
# [650 rows x 8 columns]
#
# Year: 2024
#                           Constituency Winner elected_mp_party  \
# 0                     Aberafan Maesteg    LAB              Lab
# 1                            Aldershot    CON              Con
# 2                  Aldridge-Brownhills    CON              Con
# 3             Altrincham and Sale West    LAB              Lab
# 4                     Alyn and Deeside    LAB              Lab
# ..                                 ...    ...              ...
# 645            Perth and Kinross-shire    SNP              SNP
# 646                         Rutherglen    LAB              Lab
# 647           Stirling and Strathallan    CON              Con
# 648  West Aberdeenshire and Kincardine    LAB              Lab
# 649                West Dunbartonshire    LAB              Lab
#
#     elected_mp_party_name    color constituency_id  coord_one  coord_two
# 0                  Labour  #dd0018             NaN        NaN        NaN
# 1            Conservative  #005af0       E14000530       -3.0      -11.0
# 2            Conservative  #005af0       E14000531       -3.0       -1.0
# 3                  Labour  #dd0018       E14000532       -7.0        3.0
# 4                  Labour  #dd0018       W07000043      -10.0        1.0
# ..                    ...      ...             ...        ...        ...
# 645                   SNP  #fff293             NaN        NaN        NaN
# 646                Labour  #dd0018             NaN        NaN        NaN
# 647          Conservative  #005af0             NaN        NaN        NaN
# 648                Labour  #dd0018       S14000058       -4.0       24.0
# 649                Labour  #dd0018       S14000059       -9.0       22.0
#
# [650 rows x 8 columns]
#
# Constituency Winners for model: polls_eco_df
# Year: 2010
#                           Constituency Winner elected_mp_party  \
# 0                     Aberafan Maesteg    LAB              Lab
# 1                            Aldershot    CON              Con
# 2                  Aldridge-Brownhills    CON              Con
# 3             Altrincham and Sale West    CON              Con
# 4                     Alyn and Deeside    LAB              Lab
# ..                                 ...    ...              ...
# 645            Perth and Kinross-shire    SNP              SNP
# 646                         Rutherglen    LAB              Lab
# 647           Stirling and Strathallan    CON              Con
# 648  West Aberdeenshire and Kincardine    LAB              Lab
# 649                West Dunbartonshire    LAB              Lab
#
#     elected_mp_party_name    color constituency_id  coord_one  coord_two
# 0                  Labour  #dd0018             NaN        NaN        NaN
# 1            Conservative  #005af0       E14000530       -3.0      -11.0
# 2            Conservative  #005af0       E14000531       -3.0       -1.0
# 3            Conservative  #005af0       E14000532       -7.0        3.0
# 4                  Labour  #dd0018       W07000043      -10.0        1.0
# ..                    ...      ...             ...        ...        ...
# 645                   SNP  #fff293             NaN        NaN        NaN
# 646                Labour  #dd0018             NaN        NaN        NaN
# 647          Conservative  #005af0             NaN        NaN        NaN
# 648                Labour  #dd0018       S14000058       -4.0       24.0
# 649                Labour  #dd0018       S14000059       -9.0       22.0
#
# [650 rows x 8 columns]
#
# Year: 2015
#                           Constituency Winner elected_mp_party  \
# 0                     Aberafan Maesteg    LAB              Lab
# 1                            Aldershot    CON              Con
# 2                  Aldridge-Brownhills    CON              Con
# 3             Altrincham and Sale West    CON              Con
# 4                     Alyn and Deeside    LAB              Lab
# ..                                 ...    ...              ...
# 645            Perth and Kinross-shire    SNP              SNP
# 646                         Rutherglen    SNP              SNP
# 647           Stirling and Strathallan    SNP              SNP
# 648  West Aberdeenshire and Kincardine    SNP              SNP
# 649                West Dunbartonshire    SNP              SNP
#
#     elected_mp_party_name    color constituency_id  coord_one  coord_two
# 0                  Labour  #dd0018             NaN        NaN        NaN
# 1            Conservative  #005af0       E14000530       -3.0      -11.0
# 2            Conservative  #005af0       E14000531       -3.0       -1.0
# 3            Conservative  #005af0       E14000532       -7.0        3.0
# 4                  Labour  #dd0018       W07000043      -10.0        1.0
# ..                    ...      ...             ...        ...        ...
# 645                   SNP  #fff293             NaN        NaN        NaN
# 646                   SNP  #fff293             NaN        NaN        NaN
# 647                   SNP  #fff293             NaN        NaN        NaN
# 648                   SNP  #fff293       S14000058       -4.0       24.0
# 649                   SNP  #fff293       S14000059       -9.0       22.0
#
# [650 rows x 8 columns]
#
# Year: 2017
#                           Constituency Winner elected_mp_party  \
# 0                     Aberafan Maesteg    LAB              Lab
# 1                            Aldershot    CON              Con
# 2                  Aldridge-Brownhills    CON              Con
# 3             Altrincham and Sale West    CON              Con
# 4                     Alyn and Deeside    CON              Con
# ..                                 ...    ...              ...
# 645            Perth and Kinross-shire    SNP              SNP
# 646                         Rutherglen    SNP              SNP
# 647           Stirling and Strathallan    CON              Con
# 648  West Aberdeenshire and Kincardine    SNP              SNP
# 649                West Dunbartonshire    SNP              SNP
#
#     elected_mp_party_name    color constituency_id  coord_one  coord_two
# 0                  Labour  #dd0018             NaN        NaN        NaN
# 1            Conservative  #005af0       E14000530       -3.0      -11.0
# 2            Conservative  #005af0       E14000531       -3.0       -1.0
# 3            Conservative  #005af0       E14000532       -7.0        3.0
# 4            Conservative  #005af0       W07000043      -10.0        1.0
# ..                    ...      ...             ...        ...        ...
# 645                   SNP  #fff293             NaN        NaN        NaN
# 646                   SNP  #fff293             NaN        NaN        NaN
# 647          Conservative  #005af0             NaN        NaN        NaN
# 648                   SNP  #fff293       S14000058       -4.0       24.0
# 649                   SNP  #fff293       S14000059       -9.0       22.0
#
# [650 rows x 8 columns]
#
# Year: 2019
#                           Constituency Winner elected_mp_party  \
# 0                     Aberafan Maesteg    LAB              Lab
# 1                            Aldershot    CON              Con
# 2                  Aldridge-Brownhills    CON              Con
# 3             Altrincham and Sale West    CON              Con
# 4                     Alyn and Deeside    LAB              Lab
# ..                                 ...    ...              ...
# 645            Perth and Kinross-shire    GRE            Green
# 646                         Rutherglen    GRE            Green
# 647           Stirling and Strathallan    CON              Con
# 648  West Aberdeenshire and Kincardine    GRE            Green
# 649                West Dunbartonshire    GRE            Green
#
#     elected_mp_party_name    color constituency_id  coord_one  coord_two
# 0                  Labour  #dd0018             NaN        NaN        NaN
# 1            Conservative  #005af0       E14000530       -3.0      -11.0
# 2            Conservative  #005af0       E14000531       -3.0       -1.0
# 3            Conservative  #005af0       E14000532       -7.0        3.0
# 4                  Labour  #dd0018       W07000043      -10.0        1.0
# ..                    ...      ...             ...        ...        ...
# 645                 Green  #00bc3e             NaN        NaN        NaN
# 646                 Green  #00bc3e             NaN        NaN        NaN
# 647          Conservative  #005af0             NaN        NaN        NaN
# 648                 Green  #00bc3e       S14000058       -4.0       24.0
# 649                 Green  #00bc3e       S14000059       -9.0       22.0
#
# [650 rows x 8 columns]
#
# Year: 2024
#                           Constituency Winner elected_mp_party  \
# 0                     Aberafan Maesteg    LAB              Lab
# 1                            Aldershot    CON              Con
# 2                  Aldridge-Brownhills    CON              Con
# 3             Altrincham and Sale West    CON              Con
# 4                     Alyn and Deeside    LAB              Lab
# ..                                 ...    ...              ...
# 645            Perth and Kinross-shire    SNP              SNP
# 646                         Rutherglen    LAB              Lab
# 647           Stirling and Strathallan    CON              Con
# 648  West Aberdeenshire and Kincardine    LAB              Lab
# 649                West Dunbartonshire    LAB              Lab
#
#     elected_mp_party_name    color constituency_id  coord_one  coord_two
# 0                  Labour  #dd0018             NaN        NaN        NaN
# 1            Conservative  #005af0       E14000530       -3.0      -11.0
# 2            Conservative  #005af0       E14000531       -3.0       -1.0
# 3            Conservative  #005af0       E14000532       -7.0        3.0
# 4                  Labour  #dd0018       W07000043      -10.0        1.0
# ..                    ...      ...             ...        ...        ...
# 645                   SNP  #fff293             NaN        NaN        NaN
# 646                Labour  #dd0018             NaN        NaN        NaN
# 647          Conservative  #005af0             NaN        NaN        NaN
# 648                Labour  #dd0018       S14000058       -4.0       24.0
# 649                Labour  #dd0018       S14000059       -9.0       22.0
#
# [650 rows x 8 columns]
#
# Constituency Winners for model: polls_alt_df
# Year: 2010
#                           Constituency Winner elected_mp_party  \
# 0                     Aberafan Maesteg    LAB              Lab
# 1                            Aldershot    CON              Con
# 2                  Aldridge-Brownhills    CON              Con
# 3             Altrincham and Sale West    CON              Con
# 4                     Alyn and Deeside    LAB              Lab
# ..                                 ...    ...              ...
# 645            Perth and Kinross-shire    SNP              SNP
# 646                         Rutherglen    LAB              Lab
# 647           Stirling and Strathallan    CON              Con
# 648  West Aberdeenshire and Kincardine    LAB              Lab
# 649                West Dunbartonshire    LAB              Lab
#
#     elected_mp_party_name    color constituency_id  coord_one  coord_two
# 0                  Labour  #dd0018             NaN        NaN        NaN
# 1            Conservative  #005af0       E14000530       -3.0      -11.0
# 2            Conservative  #005af0       E14000531       -3.0       -1.0
# 3            Conservative  #005af0       E14000532       -7.0        3.0
# 4                  Labour  #dd0018       W07000043      -10.0        1.0
# ..                    ...      ...             ...        ...        ...
# 645                   SNP  #fff293             NaN        NaN        NaN
# 646                Labour  #dd0018             NaN        NaN        NaN
# 647          Conservative  #005af0             NaN        NaN        NaN
# 648                Labour  #dd0018       S14000058       -4.0       24.0
# 649                Labour  #dd0018       S14000059       -9.0       22.0
#
# [650 rows x 8 columns]
#
# Year: 2015
#                           Constituency Winner elected_mp_party  \
# 0                     Aberafan Maesteg    LAB              Lab
# 1                            Aldershot    CON              Con
# 2                  Aldridge-Brownhills    CON              Con
# 3             Altrincham and Sale West    CON              Con
# 4                     Alyn and Deeside    LAB              Lab
# ..                                 ...    ...              ...
# 645            Perth and Kinross-shire    SNP              SNP
# 646                         Rutherglen    SNP              SNP
# 647           Stirling and Strathallan    SNP              SNP
# 648  West Aberdeenshire and Kincardine    SNP              SNP
# 649                West Dunbartonshire    SNP              SNP
#
#     elected_mp_party_name    color constituency_id  coord_one  coord_two
# 0                  Labour  #dd0018             NaN        NaN        NaN
# 1            Conservative  #005af0       E14000530       -3.0      -11.0
# 2            Conservative  #005af0       E14000531       -3.0       -1.0
# 3            Conservative  #005af0       E14000532       -7.0        3.0
# 4                  Labour  #dd0018       W07000043      -10.0        1.0
# ..                    ...      ...             ...        ...        ...
# 645                   SNP  #fff293             NaN        NaN        NaN
# 646                   SNP  #fff293             NaN        NaN        NaN
# 647                   SNP  #fff293             NaN        NaN        NaN
# 648                   SNP  #fff293       S14000058       -4.0       24.0
# 649                   SNP  #fff293       S14000059       -9.0       22.0
#
# [650 rows x 8 columns]
#
# Year: 2017
#                           Constituency Winner elected_mp_party  \
# 0                     Aberafan Maesteg    LAB              Lab
# 1                            Aldershot    CON              Con
# 2                  Aldridge-Brownhills    CON              Con
# 3             Altrincham and Sale West    CON              Con
# 4                     Alyn and Deeside    CON              Con
# ..                                 ...    ...              ...
# 645            Perth and Kinross-shire    SNP              SNP
# 646                         Rutherglen    SNP              SNP
# 647           Stirling and Strathallan    CON              Con
# 648  West Aberdeenshire and Kincardine    SNP              SNP
# 649                West Dunbartonshire    SNP              SNP
#
#     elected_mp_party_name    color constituency_id  coord_one  coord_two
# 0                  Labour  #dd0018             NaN        NaN        NaN
# 1            Conservative  #005af0       E14000530       -3.0      -11.0
# 2            Conservative  #005af0       E14000531       -3.0       -1.0
# 3            Conservative  #005af0       E14000532       -7.0        3.0
# 4            Conservative  #005af0       W07000043      -10.0        1.0
# ..                    ...      ...             ...        ...        ...
# 645                   SNP  #fff293             NaN        NaN        NaN
# 646                   SNP  #fff293             NaN        NaN        NaN
# 647          Conservative  #005af0             NaN        NaN        NaN
# 648                   SNP  #fff293       S14000058       -4.0       24.0
# 649                   SNP  #fff293       S14000059       -9.0       22.0
#
# [650 rows x 8 columns]
#
# Year: 2019
#                           Constituency Winner elected_mp_party  \
# 0                     Aberafan Maesteg    LAB              Lab
# 1                            Aldershot    CON              Con
# 2                  Aldridge-Brownhills    CON              Con
# 3             Altrincham and Sale West    CON              Con
# 4                     Alyn and Deeside    LAB              Lab
# ..                                 ...    ...              ...
# 645            Perth and Kinross-shire    GRE            Green
# 646                         Rutherglen    GRE            Green
# 647           Stirling and Strathallan    CON              Con
# 648  West Aberdeenshire and Kincardine    GRE            Green
# 649                West Dunbartonshire    GRE            Green
#
#     elected_mp_party_name    color constituency_id  coord_one  coord_two
# 0                  Labour  #dd0018             NaN        NaN        NaN
# 1            Conservative  #005af0       E14000530       -3.0      -11.0
# 2            Conservative  #005af0       E14000531       -3.0       -1.0
# 3            Conservative  #005af0       E14000532       -7.0        3.0
# 4                  Labour  #dd0018       W07000043      -10.0        1.0
# ..                    ...      ...             ...        ...        ...
# 645                 Green  #00bc3e             NaN        NaN        NaN
# 646                 Green  #00bc3e             NaN        NaN        NaN
# 647          Conservative  #005af0             NaN        NaN        NaN
# 648                 Green  #00bc3e       S14000058       -4.0       24.0
# 649                 Green  #00bc3e       S14000059       -9.0       22.0
#
# [650 rows x 8 columns]
#
# Year: 2024
#                           Constituency Winner elected_mp_party  \
# 0                     Aberafan Maesteg    LAB              Lab
# 1                            Aldershot    CON              Con
# 2                  Aldridge-Brownhills    CON              Con
# 3             Altrincham and Sale West    CON              Con
# 4                     Alyn and Deeside    LAB              Lab
# ..                                 ...    ...              ...
# 645            Perth and Kinross-shire    SNP              SNP
# 646                         Rutherglen    LAB              Lab
# 647           Stirling and Strathallan    CON              Con
# 648  West Aberdeenshire and Kincardine    LAB              Lab
# 649                West Dunbartonshire    LAB              Lab
#
#     elected_mp_party_name    color constituency_id  coord_one  coord_two
# 0                  Labour  #dd0018             NaN        NaN        NaN
# 1            Conservative  #005af0       E14000530       -3.0      -11.0
# 2            Conservative  #005af0       E14000531       -3.0       -1.0
# 3            Conservative  #005af0       E14000532       -7.0        3.0
# 4                  Labour  #dd0018       W07000043      -10.0        1.0
# ..                    ...      ...             ...        ...        ...
# 645                   SNP  #fff293             NaN        NaN        NaN
# 646                Labour  #dd0018             NaN        NaN        NaN
# 647          Conservative  #005af0             NaN        NaN        NaN
# 648                Labour  #dd0018       S14000058       -4.0       24.0
# 649                Labour  #dd0018       S14000059       -9.0       22.0
#
# [650 rows x 8 columns]
#
# Constituency Winners for model: polls_eco_alt_df
# Year: 2010
#                           Constituency Winner elected_mp_party  \
# 0                     Aberafan Maesteg    LAB              Lab
# 1                            Aldershot    CON              Con
# 2                  Aldridge-Brownhills    CON              Con
# 3             Altrincham and Sale West    CON              Con
# 4                     Alyn and Deeside    LAB              Lab
# ..                                 ...    ...              ...
# 645            Perth and Kinross-shire    SNP              SNP
# 646                         Rutherglen    LAB              Lab
# 647           Stirling and Strathallan    CON              Con
# 648  West Aberdeenshire and Kincardine    LAB              Lab
# 649                West Dunbartonshire    LAB              Lab
#
#     elected_mp_party_name    color constituency_id  coord_one  coord_two
# 0                  Labour  #dd0018             NaN        NaN        NaN
# 1            Conservative  #005af0       E14000530       -3.0      -11.0
# 2            Conservative  #005af0       E14000531       -3.0       -1.0
# 3            Conservative  #005af0       E14000532       -7.0        3.0
# 4                  Labour  #dd0018       W07000043      -10.0        1.0
# ..                    ...      ...             ...        ...        ...
# 645                   SNP  #fff293             NaN        NaN        NaN
# 646                Labour  #dd0018             NaN        NaN        NaN
# 647          Conservative  #005af0             NaN        NaN        NaN
# 648                Labour  #dd0018       S14000058       -4.0       24.0
# 649                Labour  #dd0018       S14000059       -9.0       22.0
#
# [650 rows x 8 columns]
#
# Year: 2015
#                           Constituency Winner elected_mp_party  \
# 0                     Aberafan Maesteg    LAB              Lab
# 1                            Aldershot    CON              Con
# 2                  Aldridge-Brownhills    CON              Con
# 3             Altrincham and Sale West    CON              Con
# 4                     Alyn and Deeside    LAB              Lab
# ..                                 ...    ...              ...
# 645            Perth and Kinross-shire    SNP              SNP
# 646                         Rutherglen    SNP              SNP
# 647           Stirling and Strathallan    SNP              SNP
# 648  West Aberdeenshire and Kincardine    SNP              SNP
# 649                West Dunbartonshire    SNP              SNP
#
#     elected_mp_party_name    color constituency_id  coord_one  coord_two
# 0                  Labour  #dd0018             NaN        NaN        NaN
# 1            Conservative  #005af0       E14000530       -3.0      -11.0
# 2            Conservative  #005af0       E14000531       -3.0       -1.0
# 3            Conservative  #005af0       E14000532       -7.0        3.0
# 4                  Labour  #dd0018       W07000043      -10.0        1.0
# ..                    ...      ...             ...        ...        ...
# 645                   SNP  #fff293             NaN        NaN        NaN
# 646                   SNP  #fff293             NaN        NaN        NaN
# 647                   SNP  #fff293             NaN        NaN        NaN
# 648                   SNP  #fff293       S14000058       -4.0       24.0
# 649                   SNP  #fff293       S14000059       -9.0       22.0
#
# [650 rows x 8 columns]
#
# Year: 2017
#                           Constituency Winner elected_mp_party  \
# 0                     Aberafan Maesteg    LAB              Lab
# 1                            Aldershot    CON              Con
# 2                  Aldridge-Brownhills    CON              Con
# 3             Altrincham and Sale West    CON              Con
# 4                     Alyn and Deeside    CON              Con
# ..                                 ...    ...              ...
# 645            Perth and Kinross-shire    SNP              SNP
# 646                         Rutherglen    SNP              SNP
# 647           Stirling and Strathallan    CON              Con
# 648  West Aberdeenshire and Kincardine    SNP              SNP
# 649                West Dunbartonshire    SNP              SNP
#
#     elected_mp_party_name    color constituency_id  coord_one  coord_two
# 0                  Labour  #dd0018             NaN        NaN        NaN
# 1            Conservative  #005af0       E14000530       -3.0      -11.0
# 2            Conservative  #005af0       E14000531       -3.0       -1.0
# 3            Conservative  #005af0       E14000532       -7.0        3.0
# 4            Conservative  #005af0       W07000043      -10.0        1.0
# ..                    ...      ...             ...        ...        ...
# 645                   SNP  #fff293             NaN        NaN        NaN
# 646                   SNP  #fff293             NaN        NaN        NaN
# 647          Conservative  #005af0             NaN        NaN        NaN
# 648                   SNP  #fff293       S14000058       -4.0       24.0
# 649                   SNP  #fff293       S14000059       -9.0       22.0
#
# [650 rows x 8 columns]
#
# Year: 2019
#                           Constituency Winner elected_mp_party  \
# 0                     Aberafan Maesteg    LAB              Lab
# 1                            Aldershot    CON              Con
# 2                  Aldridge-Brownhills    CON              Con
# 3             Altrincham and Sale West    CON              Con
# 4                     Alyn and Deeside    LAB              Lab
# ..                                 ...    ...              ...
# 645            Perth and Kinross-shire    GRE            Green
# 646                         Rutherglen    GRE            Green
# 647           Stirling and Strathallan    CON              Con
# 648  West Aberdeenshire and Kincardine    GRE            Green
# 649                West Dunbartonshire    GRE            Green
#
#     elected_mp_party_name    color constituency_id  coord_one  coord_two
# 0                  Labour  #dd0018             NaN        NaN        NaN
# 1            Conservative  #005af0       E14000530       -3.0      -11.0
# 2            Conservative  #005af0       E14000531       -3.0       -1.0
# 3            Conservative  #005af0       E14000532       -7.0        3.0
# 4                  Labour  #dd0018       W07000043      -10.0        1.0
# ..                    ...      ...             ...        ...        ...
# 645                 Green  #00bc3e             NaN        NaN        NaN
# 646                 Green  #00bc3e             NaN        NaN        NaN
# 647          Conservative  #005af0             NaN        NaN        NaN
# 648                 Green  #00bc3e       S14000058       -4.0       24.0
# 649                 Green  #00bc3e       S14000059       -9.0       22.0
#
# [650 rows x 8 columns]
#
# Year: 2024
#                           Constituency Winner elected_mp_party  \
# 0                     Aberafan Maesteg    LAB              Lab
# 1                            Aldershot    CON              Con
# 2                  Aldridge-Brownhills    CON              Con
# 3             Altrincham and Sale West    LAB              Lab
# 4                     Alyn and Deeside    LAB              Lab
# ..                                 ...    ...              ...
# 645            Perth and Kinross-shire    SNP              SNP
# 646                         Rutherglen    LAB              Lab
# 647           Stirling and Strathallan    CON              Con
# 648  West Aberdeenshire and Kincardine    LAB              Lab
# 649                West Dunbartonshire    LAB              Lab
#
#     elected_mp_party_name    color constituency_id  coord_one  coord_two
# 0                  Labour  #dd0018             NaN        NaN        NaN
# 1            Conservative  #005af0       E14000530       -3.0      -11.0
# 2            Conservative  #005af0       E14000531       -3.0       -1.0
# 3                  Labour  #dd0018       E14000532       -7.0        3.0
# 4                  Labour  #dd0018       W07000043      -10.0        1.0
# ..                    ...      ...             ...        ...        ...
# 645                   SNP  #fff293             NaN        NaN        NaN
# 646                Labour  #dd0018             NaN        NaN        NaN
# 647          Conservative  #005af0             NaN        NaN        NaN
# 648                Labour  #dd0018       S14000058       -4.0       24.0
# 649                Labour  #dd0018       S14000059       -9.0       22.0
#
# [650 rows x 8 columns]
